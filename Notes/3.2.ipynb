# %%
import requests as r

# %%
url='https://www.vinted.fr/api/v2/items?catalog_ids=1193&color_ids=&brand_ids=&size_ids=&material_ids=&status_ids=&country_ids=&city_ids=&is_for_swap=0&page=2&per_page=24&time=1606217432&search_session_id=37d91f8e-0c9f-4fcd-a64b-5802ea048fa4'

# %%
r.get(url)
# Out:
# <Response [401]>

# %%
headers="""accept: application/json, text/plain, */*
accept-encoding: gzip, deflate, br
accept-language: fr
cache-control: no-cache
cookie: __cfduid=def393e68d18f0de189887797435429211606217287; anon_id=377020f0-efe2-49b4-ad8a-497db4b0c9c5; __cf_bm=ac27fc9912f106a84e7f82e97c72118b8ec64717-1606217290-1800-AUpszaLeW2XXybI209bGY4RRJ6j+SW1MUxheJle8j/udzFM7qxFP/cf+ir9uwKnttDivO3gzqfqKCZGR60xe2dLHy7d9kAb2PjwLW4vaVMhVvZ/KEI3pXmQt7dgq4UftNSEPeiWnyB0CmNXMpZoBs8lraJU4s7LX/CRRC9CGTdL9hStjg0BJgMgZRoWcA/NdjQ==; G_ENABLED_IDPS=google; OptanonAlertBoxClosed=2020-11-24T11:28:18.573Z; eupubconsent-v2=CO9YU8EO9YU8EAcABBENBBCsAP_AAH_AAChQGXNf_X9fb2vj-_5999t0eY1f9_63t2wzjgeNs-8NyZ_X_J4XtmMyvB34pqYKmR4EunLBAQdlHGHcTQgAwIkVqTLsYk2MjzNKJ7JEilMbe2dYGH9vn8XT-ZKY70-v___7v3-_-___7pAy6BWABQAEQAKgAhgBFACYAFwAMwAjoBhAGHAMoAywBqADaAHhAPsA_ACAQEYARkAjgBIgCfAFLAKvAWgBaQC_AG8AOkAj0BIICYgEygJsAU2AsUBaIC2AFyALzAX0AwKBh4GIAMegZEBkYDLgEQQAIA-wC9ggCQAAUADgAPAAuAB8AHwASQAxAB_AEUAJEAZoA2gBxADkAHOAOoAf4BAwCDgEXAI0AT8AoYCHwEegJWATaAsIBaAC6AF1ALtAYgAxYBkIDKAkEoABAAC4AKAAqABkADgAHgAQAAiABUADQAHkAQwBEACYAE-...-_wCLAEYAI4ASkAq4BYoC0ALSAXMAvIBfgDCAGKANoAbiA6YDqAHoAQ2AiIBF4CQQEiAJUATYAnYBQ4CmgFWALFgWwBbIC4AFyALtAXeAwkBhoDDwGJAMYAY8AyQBk5ABEAAgAH4AQQAvgBoAD-AJEAW4AwgBlgDVAG0AOIAcgA5wB4AFLALEAYAA2QBvADtgIfAR6AlcBMQCbQFCgKQAUmArYBdAC-gGBEIGYACwAKAAZABEACoAGIAQwAmABVAC4AGIAMwAbwA9ACOAFiAMoAagA3wB3gD8AH-AQMAjABHACUgFDAKvAWgBaQC5gF--AGQANoAjgBIgC5AGEAMsAagA1wBtADiAHOAOoAdwA8ACAAEHAISARUAm0BPgE_AKWAWIAuoBgADFAGvAN4AdsA8gB_wEegJiATaApABTACpgFdgLQAXQAvoBgQDFikD4ABcAFAAVAAyABwAEAAKgAYgA0AB5AEMARAAmABPACkAFUALAAXAAxABmADmAIQAQ0AiACJAFKALEAW4AygBogDVAGyAO-AfYB-gEWAIwARwAlIBQwCrgFbALmAXkAwgBtADcAHoAReAkQBNgCdgFDgKaAVsAsUBbAC4AFyALtAYaAw8BjADIgGSAMnAA.f_gAD_gAAAAA; feature.expose.377020f0-efe2-49b4-ad8a-497db4b0c9c5=%5B%22sqp_ads%22%2C%22final_discovery_homepage%22%2C%22homepage_brand_image_5%22%2C%22nasa_delivery_instructions_redesign%22%2C%22disable_boosts_for_new_buyers%22%2C%22location_city_country%22%5D; _ga=GA1.2.1706906247.1606217303; _gid=GA1.2.1904756917.1606217303; _gat=1; _vinted_fr_session=...--69248592df3986d640d8386aad7fe9ad12a92e65; OptanonConsent=isIABGlobal=false&datestamp=Tue+Nov+24+2020+12%3A30%3A37+GMT%2B0100+(Central+European+Standard+Time)&version=6.7.0&hosts=&consentId=de152a64-3557-48e1-af64-5c3bab51b0a9&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1%2CSTACK42%3A1&geolocation=FR%3BIDF&AwaitingReconsent=false
dnt: 1
pragma: no-cache
referer: https://www.vinted.fr/vetements?catalog[]=1193&time=1606217432&page=2
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36 OPR/71.0.3770.323
x-csrf-token: ikDuUVA6muVPFyyVmce3n0hTYkAD7wdHiiTwINsweaCX4bcexs3D4smcCguFWrdzb4kh1gXQPdIs5/2X7FRv2Q=="""

# %%
headers=dict([i.split(': ') for i in headers.split('\n')])

# %%
response=r.get(url, headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '{"items":[{"id":745337744,"title":"Vends ensemble obaibi 18 M neuf ","brand_id":174100,"size_id":619,"status_id":6,"disposal_conditions":4,"user_id":14869438,"owner_id":null,"country_id":16,"catalog_id":1517,"color1_id":12,"color2_id":27,"package_size_id":2,"is_hidden":0,"is_reserved":0,"reserved_for_user_id":null,"is_visible":1,"is_unisex":0,"is_closed":0,"is_admin_alerted":false,"active_bid_count":1,"favourite_count":2,"view_count":15,"moderation_status":0,"last_push_up_at":"2020-11-23T12:18:49+01:00","description":"Vends lot 18  M marque Obaibi comprenant un collant hiver blanc à paillette. Un gilet avec des motifs chats. Une blouse et un short jupe. Tout est neuf encore avec les étiquettes valeur 56 euros ","package_size_standard":true,"item_closing_action":null,"related_catalog_ids":[],"related_catalogs_enabled":false,"size":"18-24 mois / 86-92 cm","brand":"Obaïbi","composition":"","extra_conditions":"","is_for_sell":true,"is_for_swap":false,"is_for_give_away":false,"is_handicraft":false,"is_draft":false,"label":"Obaïbi","real_value_numeric":null,"original_price_numeric":"40.0","price_numeric":"30.0","currency":"\\u20ac","created_at_ts":"2020-11-18T16:53:17+01:00","updated_at_ts":"2020-11-24T12:20:02+01:00","user_updated_at_ts":"2020-11-24T12:20:02+01:00","photos":[{"id":2605354342,"image_no":1,"width":800,"height":600,"dominant_color":"#968574","dominant_color_opaque":"#E0DAD5","url":"https://images.vinted.net/thumbs/f800/02_0118b_TxGJCKJoagCBdTQsWCb9vXKF.jpeg?1605714797-8b77193947ce6764c7916a5817c8ca6470dd1a03","is_main":true,"thumbnails":[{"type":"thumb70x100","url":"https://images.vinted.net/thumbs/70x100/02_0118b_TxGJCKJoagCBdTQsWCb9vXKF.jpeg?1605714797-92c64c8aca2760251dffd753ee7c2487de8a036e","width":70,"height":100,"original_size":null},{"type":"thumb150x210","url":"https://images.vinted.net/thumbs/150x210/02_0118b_TxGJCKJoagCBdTQsWCb9vXKF.jpeg?1605714797-13d8ca7f24abbcdf9892d1bf14d2735bb482b6c5","width":150,"height":210,"original_size":null},{"type":"thumb310x430","url":"https://images.vinted.net/thumbs/310x430/02_0118b_TxGJCKJoagCBdTQsWCb9vXKF.jpeg?1605714797-9384a1a92143330aff0ad13fcd5bdaf1798232fd","width":310,"height":430,"original_size":null},{"type":"thumb428x624","url":"https://images.vinted.net/thumbs/f800/02_0118b_TxGJCKJoagCBdTQsWCb9vXKF.jpeg?1605714797-8b77193947ce6764c7916a5817c8ca6470dd1a03","width":428,"height":321,"original_size":true},{"type":"thumb624x428","url":"https://images.vinted.net/thumbs/f800/02_0118b_TxGJCKJoagCBdTQsWCb9vXKF.jpeg?1605714797-8b77193947ce6764c7916a5817c8ca6470dd1a03","width":624,"height":468,"original_size":true},{"type":"thumb364x428","url":"https://images.vinted.net/thumbs/f800/02_0118b_TxGJCKJoagCBdTQsWCb9vXKF.jpeg?1605714797-8b77193947ce6764c7916a5817c8ca6470dd1a03","width":364,"height":273,"original_size":true}],"high_resolution":{"id":"02_0118b_TxGJCKJoagCBdTQsWCb9vXKF","timestamp":1605714797,"orientation":null},"is_suspicious":false,"full_size_url":"https://images.vinted.net/thumbs/02_0118b_TxGJCKJoagCBdTQsWCb9vXKF.jpeg?1605714797-aa4ae87adea0201504407580f9eca32fe31d610e"},{"id":2605354662,"image_no":2,"width":800,"height":600,"dominant_color":"#363E4F","dominant_color_opaque":"#C3C5CA","url":"https://images.vinted.net/thumbs/f800/02_02294_zGwxpjqRxE8BBVFPpC9Z7TEx.jpeg?1605714797-cb304ad10b116e8a20b5e39383ebd8965879ef4c","is_main":false,"thumbnails":[{"type":"thumb70x100","url":"https://images.vinted.net/thumbs/70x100/02_02294_zGwxpjqRxE8BBVFPpC9Z7TEx.jpeg?1605714797-dba479bf5c309dadeb6980214d2f5e2caeedc6de","width":70,"height":100,"original_size":null},{"type":"thumb150x210","url":"https://images.vinted.net/thumbs/150x210/02_02294_zGwxpjqRxE8BBVFPpC9Z7TEx.jpeg?1605714797-5f2553d999a3da11e7977bcbcc89a63b431a9079","width":150,"height":210,"original_size":null},{"type":"thumb310x430","url":"https://images.vinted.net/thumbs/310x430/02_02294_zGwxpjqRxE8BBVFPpC9Z7TEx.jpeg?1605714797-38022c51799b5fa9c9e0af63341f95462ec9b0a7","width":310,"height":430,"original_size":null} ...

# %%
data=response.json()

# %%
data.keys()
# Out:
# dict_keys(['items', 'item_scores_by_id', 'pagination', 'search_correlation_id', 'search_session_id', 'code'])

# %%
data['items']
# Out:
# [{'id': 745337744,
#   'title': 'Vends ensemble obaibi 18 M neuf ',
#   'brand_id': 174100,
#   'size_id': 619,
#   'status_id': 6,
#   'disposal_conditions': 4,
#   'user_id': 14869438,
#   'owner_id': None,
#   'country_id': 16,
#   'catalog_id': 1517,
#   'color1_id': 12,
#   'color2_id': 27,
#   'package_size_id': 2,
#   'is_hidden': 0,
#   'is_reserved': 0,
#   'reserved_for_user_id': None,
#   'is_visible': 1,
#   'is_unisex': 0,
#   'is_closed': 0,
#   'is_admin_alerted': False,
#   'active_bid_count': 1,
#   'favourite_count': 2,
#   'view_count': 15,
#   'moderation_status': 0,
#   'last_push_up_at': '2020-11-23T12:18:49+01:00',
#   'description': 'Vends lot 18  M marque Obaibi comprenant un collant hiver blanc à paillette. Un gilet avec des motifs chats. Une blouse et un short jupe. Tout est neuf encore avec les étiquettes valeur 56 euros ',
#   'package_size_standard': True,
#   'item_closing_action': None,
#   'related_catalog_ids': [],
#   'related_catalogs_enabled': False,
#   'size': '18-24 mois / 86-92 cm',
#   'brand': 'Obaïbi',
#   'composition': '',
#   'extra_conditions': '',
#   'is_for_sell': True,
#   'is_for_swap': False,
#   'is_for_give_away': False,
#   'is_handicraft': False,
#   'is_draft': False,
#   'label': 'Obaïbi',
#   'real_value_numeric': None,
#   'original_price_numeric': '40.0',
#   'price_numeric': '30.0',
#   'currency': '€',
#   'created_at_ts': '2020-11-18T16:53:17+01:00',
#   'updated_at_ts': '2020-11-24T12:20:02+01:00',
#   'user_updated_at_ts': '2020-11-24T12:20:02+01:00',
#   'photos': [{'id': 2605354342,
#     'image_no': 1,
#     'width': 800,
#     'height': 600,
#     'dominant_color': '#968574',
#     'dominant_color_opaque': '#E0DAD5',
#     'url': 'https://images.vinted.net/thumbs/f800/02_0118b_TxGJCKJoagCBdTQsWCb9vXKF.jpeg?1605714797-8b77193947ce6764c7916a5817c8ca6470dd1a03',
#     'is_main': True,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_0118b_TxGJCKJoagCBdTQsWCb9vXKF.jpeg?1605714797-92c64c8aca2760251dffd753ee7c2487de8a036e',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_0118b_TxGJCKJoagCBdTQsWCb9vXKF.jpeg?1605714797-13d8ca7f24abbcdf9892d1bf14d2735bb482b6c5',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_0118b_TxGJCKJoagCBdTQsWCb9vXKF.jpeg?1605714797-9384a1a92143330aff0ad13fcd5bdaf1798232fd',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_0118b_TxGJCKJoagCBdTQsWCb9vXKF.jpeg?1605714797-8b77193947ce6764c7916a5817c8ca6470dd1a03',
#       'width': 428,
#       'height': 321,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_0118b_TxGJCKJoagCBdTQsWCb9vXKF.jpeg?1605714797-8b77193947ce6764c7916a5817c8ca6470dd1a03',
#       'width': 624,
#       'height': 468,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_0118b_TxGJCKJoagCBdTQsWCb9vXKF.jpeg?1605714797-8b77193947ce6764c7916a5817c8ca6470dd1a03',
#       'width': 364,
#       'height': 273,
#       'original_size': True}],
#     'high_resolution': {'id': '02_0118b_TxGJCKJoagCBdTQsWCb9vXKF',
#      'timestamp': 1605714797,
#      'orientation': None},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_0118b_TxGJCKJoagCBdTQsWCb9vXKF.jpeg?1605714797-aa4ae87adea0201504407580f9eca32fe31d610e'},
#    {'id': 2605354662,
#     'image_no': 2,
#     'width': 800,
#     'height': 600,
#     'dominant_color': '#363E4F',
#     'dominant_color_opaque': '#C3C5CA',
#     'url': 'https://images.vinted.net/thumbs/f800/02_02294_zGwxpjqRxE8BBVFPpC9Z7TEx.jpeg?1605714797-cb304ad10b116e8a20b5e39383ebd8965879ef4c',
#     'is_main': False,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_02294_zGwxpjqRxE8BBVFPpC9Z7TEx.jpeg?1605714797-dba479bf5c309dadeb6980214d2f5e2caeedc6de',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_02294_zGwxpjqRxE8BBVFPpC9Z7TEx.jpeg?1605714797-5f2553d999a3da11e7977bcbcc89a63b431a9079',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_02294_zGwxpjqRxE8BBVFPpC9Z7TEx.jpeg?1605714797-38022c51799b5fa9c9e0af63341f95462ec9b0a7',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_02294_zGwxpjqRxE8BBVFPpC9Z7TEx.jpeg?1605714797-cb304ad10b116e8a20b5e39383ebd8965879ef4c',
#       'width': 428,
#       'height': 321,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_02294_zGwxpjqRxE8BBVFPpC9Z7TEx.jpeg?1605714797-cb304ad10b116e8a20b5e39383ebd8965879ef4c',
#       'width': 624,
#       'height': 468,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_02294_zGwxpjqRxE8BBVFPpC9Z7TEx.jpeg?1605714797-cb304ad10b116e8a20b5e39383ebd8965879ef4c',
#       'width': 364,
#       'height': 273,
#       'original_size': True}],
#     'high_resolution': {'id': '02_02294_zGwxpjqRxE8BBVFPpC9Z7TEx',
#      'timestamp': 1605714797,
#      'orientation': None},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_02294_zGwxpjqRxE8BBVFPpC9Z7TEx.jpeg?1605714797-93d071a98e751ddbe6c925cf62871ae8c3593dc4'},
#    {'id': 2605355134,
#     'image_no': 3,
#     'width': 800,
#     'height': 600,
#     'dominant_color': '#A39F9D',
#     'dominant_color_opaque': '#E3E2E2',
#     'url': 'https://images.vinted.net/thumbs/f800/02_0193d_ZP15h955YgRYmvw8Eeu5rMKU.jpeg?1605714797-cbc9b0900eff3a36f5d699b3f901004bb0b74ad5',
#     'is_main': False,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_0193d_ZP15h955YgRYmvw8Eeu5rMKU.jpeg?1605714797-67160024311a2f77db77b79b3da0c15d65bba0fa',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_0193d_ZP15h955YgRYmvw8Eeu5rMKU.jpeg?1605714797-8baeb9212895fc75cccdde05389f39a4dc3c01bb',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_0193d_ZP15h955YgRYmvw8Eeu5rMKU.jpeg?1605714797-a4422d9512a3cd1c131c1f85ce9f1dc54df457d4',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_0193d_ZP15h955YgRYmvw8Eeu5rMKU.jpeg?1605714797-cbc9b0900eff3a36f5d699b3f901004bb0b74ad5',
#       'width': 428,
#       'height': 321,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_0193d_ZP15h955YgRYmvw8Eeu5rMKU.jpeg?1605714797-cbc9b0900eff3a36f5d699b3f901004bb0b74ad5',
#       'width': 624,
#       'height': 468,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_0193d_ZP15h955YgRYmvw8Eeu5rMKU.jpeg?1605714797-cbc9b0900eff3a36f5d699b3f901004bb0b74ad5',
#       'width': 364,
#       'height': 273,
#       'original_size': True}],
#     'high_resolution': {'id': '02_0193d_ZP15h955YgRYmvw8Eeu5rMKU',
#      'timestamp': 1605714797,
#      'orientation': None},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_0193d_ZP15h955YgRYmvw8Eeu5rMKU.jpeg?1605714797-d038b7079361740de6445f16a671ff67587d0492'},
#    {'id': 2605355940,
#     'image_no': 4,
#     'width': 800,
#     'height': 600,
#     'dominant_color': '#B3ACA5',
#     'dominant_color_opaque': '#E8E6E4',
#     'url': 'https://images.vinted.net/thumbs/f800/02_001e5_rHNxd2ncENb9d6Xkt6rKBT92.jpeg?1605714797-6ffe0e29ead67d2a6128086b14eadf67247edad7',
#     'is_main': False,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_001e5_rHNxd2ncENb9d6Xkt6rKBT92.jpeg?1605714797-f41f7453ee32966e135349de4e0d5f2dcba7a009',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_001e5_rHNxd2ncENb9d6Xkt6rKBT92.jpeg?1605714797-90fa145216cf097c6081d6c3a9bb89b42a7e86ac',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_001e5_rHNxd2ncENb9d6Xkt6rKBT92.jpeg?1605714797-c0a038e3e1e0b2714c4d692a5bffc9ff1a9d5257',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_001e5_rHNxd2ncENb9d6Xkt6rKBT92.jpeg?1605714797-6ffe0e29ead67d2a6128086b14eadf67247edad7',
#       'width': 428,
#       'height': 321,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_001e5_rHNxd2ncENb9d6Xkt6rKBT92.jpeg?1605714797-6ffe0e29ead67d2a6128086b14eadf67247edad7',
#       'width': 624,
#       'height': 468,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_001e5_rHNxd2ncENb9d6Xkt6rKBT92.jpeg?1605714797-6ffe0e29ead67d2a6128086b14eadf67247edad7',
#       'width': 364,
#       'height': 273,
#       'original_size': True}],
#     'high_resolution': {'id': '02_001e5_rHNxd2ncENb9d6Xkt6rKBT92',
#      'timestamp': 1605714797,
#      'orientation': None},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_001e5_rHNxd2ncENb9d6Xkt6rKBT92.jpeg?1605714797-315eae8e1b8268dff69c0ef049d24db2645b47dd'},
#    {'id': 2605357083,
#     'image_no': 5,
#     'width': 600,
#     'height': 800,
#     'dominant_color': '#B4B0AD',
#     'dominant_color_opaque': '#E9E7E6',
#     'url': 'https://images.vinted.net/thumbs/f800/02_00f6a_omt1PcivZA5UCussNZF1XEAX.jpeg?1605714797-5640bb462e43d74ed8b6ab3ec264d7cb4b3ffa14',
#     'is_main': False,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_00f6a_omt1PcivZA5UCussNZF1XEAX.jpeg?1605714797-652683aaaf94ec1b5ff94057d736e02b9561fcc3',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_00f6a_omt1PcivZA5UCussNZF1XEAX.jpeg?1605714797-873d1660368aaf87bb21cbee08d5c769a2b1dc35',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_00f6a_omt1PcivZA5UCussNZF1XEAX.jpeg?1605714797-8a5621fc5f42b9485d76e5e8e9464a33b058b803',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_00f6a_omt1PcivZA5UCussNZF1XEAX.jpeg?1605714797-5640bb462e43d74ed8b6ab3ec264d7cb4b3ffa14',
#       'width': 321,
#       'height': 428,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_00f6a_omt1PcivZA5UCussNZF1XEAX.jpeg?1605714797-5640bb462e43d74ed8b6ab3ec264d7cb4b3ffa14',
#       'width': 468,
#       'height': 624,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_00f6a_omt1PcivZA5UCussNZF1XEAX.jpeg?1605714797-5640bb462e43d74ed8b6ab3ec264d7cb4b3ffa14',
#       'width': 273,
#       'height': 364,
#       'original_size': True}],
#     'high_resolution': {'id': '02_00f6a_omt1PcivZA5UCussNZF1XEAX',
#      'timestamp': 1605714797,
#      'orientation': None},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_00f6a_omt1PcivZA5UCussNZF1XEAX.jpeg?1605714797-cc40afa2b0859bce1a7c6abcddfbbdd1463aba32'},
#    {'id': 2605358018,
#     'image_no': 6,
#     'width': 800,
#     'height': 600,
#     'dominant_color': '#B1AAA5',
#     'dominant_color_opaque': '#E8E6E4',
#     'url': 'https://images.vinted.net/thumbs/f800/02_00cc9_4J5pHPm5SE1Tat8Ru8qM4Yox.jpeg?1605714797-bc6ab049be68f701b34900cc9dab21e5335d169c',
#     'is_main': False,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_00cc9_4J5pHPm5SE1Tat8Ru8qM4Yox.jpeg?1605714797-45af6309070449fdf6f3119b093fb29143e1f72c',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_00cc9_4J5pHPm5SE1Tat8Ru8qM4Yox.jpeg?1605714797-c4b12cbd336232e8160c85148943247e0d909c41',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_00cc9_4J5pHPm5SE1Tat8Ru8qM4Yox.jpeg?1605714797-78380a48ce404ee925bf4a0e9639ecce408ca484',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_00cc9_4J5pHPm5SE1Tat8Ru8qM4Yox.jpeg?1605714797-bc6ab049be68f701b34900cc9dab21e5335d169c',
#       'width': 428,
#       'height': 321,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_00cc9_4J5pHPm5SE1Tat8Ru8qM4Yox.jpeg?1605714797-bc6ab049be68f701b34900cc9dab21e5335d169c',
#       'width': 624,
#       'height': 468,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_00cc9_4J5pHPm5SE1Tat8Ru8qM4Yox.jpeg?1605714797-bc6ab049be68f701b34900cc9dab21e5335d169c',
#       'width': 364,
#       'height': 273,
#       'original_size': True}],
#     'high_resolution': {'id': '02_00cc9_4J5pHPm5SE1Tat8Ru8qM4Yox',
#      'timestamp': 1605714797,
#      'orientation': None},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_00cc9_4J5pHPm5SE1Tat8Ru8qM4Yox.jpeg?1605714797-b9d062cff48dd1bd420146c9a4635b4bcabe9319'}],
#   'push_up_interval': 604800,
#   'can_be_sold': True,
#   'can_feedback': False,
#   'path': '/enfants/bebe-filles-ensembles/745337744-vends-ensemble-obaibi-18-m-neuf',
#   'possible_to_request_reservation': True,
#   'item_reservation_id': None,
#   'receiver_id': None,
#   'promoted_until': '2020-11-30T12:18:49+01:00',
#   'discount_price_numeric': None,
#   'badge': None,
#   'reservation_requests_from_users': [],
#   'material_id': None,
#   'author': None,
#   'book_title': None,
#   'isbn': None,
#   'defect_ids': [],
#   'user': {'id': 14869438,
#    'anon_id': '5c68f87c-f98f-4a54-a051-149a80cc76d0',
#    'login': 'meg69400',
#    'real_name': None,
#    'email': None,
#    'birthday': None,
#    'gender': 'F',
#    'item_count': 15,
#    'msg_template_count': 4,
#    'given_item_count': 16,
#    'taken_item_count': 367,
#    'favourite_topic_count': 0,
#    'forum_msg_count': 0,
#    'forum_topic_count': 0,
#    'followers_count': 4,
#    'following_count': 0,
#    'following_brands_count': 0,
#    'positive_feedback_count': 73,
#    'neutral_feedback_count': 0,
#    'negative_feedback_count': 1,
#    'meeting_transaction_count': 0,
#    'account_status': 0,
#    'email_bounces': None,
#    'feedback_reputation': 0.986,
#    'account_ban_date': None,
#    'forum_ban_date': None,
#    'is_on_holiday': False,
#    'is_publish_photos_agreed': True,
#    'is_shadow_banned': False,
#    'is_identity': False,
#    'expose_location': True,
#    'third_party_tracking': True,
#    'default_address': None,
#    'created_at': '2017-12-26T17:44:04+01:00',
#    'last_loged_on_ts': '2020-11-24T10:34:28+01:00',
#    'city_id': 79124,
#    'city': 'Gleizé',
#    'country_id': 16,
#    'country_code': 'FR',
#    'country_title_local': 'France',
#    'country_title': 'France',
#    'contacts_permission': None,
#    'contacts': None,
#    'photo': {'id': 7454854,
#     'width': 796,
#     'height': 800,
#     'temp_uuid': None,
#     'url': 'https://images.vinted.net/thumbs/f800/02_00dd7_q3xbuhcoEywJwPatTWziajiB.jpeg?1605208648-342c95fd2f9cc62e1e0d79205687a8b3938f2982',
#     'dominant_color': '#31abc2',
#     'dominant_color_opaque': '#C1E6ED',
#     'thumbnails': [{'type': 'thumb310',
#       'url': 'https://images.vinted.net/thumbs/310x310/02_00dd7_q3xbuhcoEywJwPatTWziajiB.jpeg?1605208648-cc0e7ea869e8d64fd336cf5e0c6f2b822417759e',
#       'width': 310,
#       'height': 310,
#       'original_size': None},
#      {'type': 'thumb150',
#       'url': 'https://images.vinted.net/thumbs/150x150/02_00dd7_q3xbuhcoEywJwPatTWziajiB.jpeg?1605208648-d86272df6817e3ec1ecaa2855c4ea44ecb41a7df',
#       'width': 150,
#       'height': 150,
#       'original_size': None},
#      {'type': 'thumb100',
#       'url': 'https://images.vinted.net/thumbs/100x100/02_00dd7_q3xbuhcoEywJwPatTWziajiB.jpeg?1605208648-29fb28cf5cef0f1d0ebbe928d0dfb054884d0f80',
#       'width': 100,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb50',
#       'url': 'https://images.vinted.net/thumbs/50x50/02_00dd7_q3xbuhcoEywJwPatTWziajiB.jpeg?1605208648-f50b4f0fe38c08a6da61d82b188947e3de89c984',
#       'width': 50,
#       'height': 50,
#       'original_size': None},
#      {'type': 'thumb20',
#       'url': 'https://images.vinted.net/thumbs/20x20/02_00dd7_q3xbuhcoEywJwPatTWziajiB.jpeg?1605208648-5e24e40d3504ad235b16fe52db8e6583b7f4489b',
#       'width': 20,
#       'height': 20,
#       'original_size': None}],
#     'is_suspicious': False,
#     'orientation': None,
#     'high_resolution': {'id': '02_00dd7_q3xbuhcoEywJwPatTWziajiB',
#      'timestamp': 1605208648,
#      'orientation': None},
#     'full_size_url': 'https://images.vinted.net/thumbs/02_00dd7_q3xbuhcoEywJwPatTWziajiB.jpeg?1605208648-55962c54b1491cfb654b2d6c3cca7f200226b84f'},
#    'path': '/member/14869438-meg69400',
#    'is_god': False,
#    'is_tester': False,
#    'moderator': False,
#    'volunteer_moderator': False,
#    'hide_feedback': False,
#    'can_post_big_forum_photos': False,
#    'allow_direct_messaging': True,
#    'bundle_discount': {'id': 1796357,
#     'user_id': 14869438,
#     'enabled': False,
#     'minimal_item_count': 2,
#     'fraction': '0.25',
#     'discounts': [{'minimal_item_count': 2, 'fraction': '0.25'},
#      {'minimal_item_count': 3, 'fraction': '0.3'},
#      {'minimal_item_count': 5, 'fraction': '0.5'}]},
#    'donation_configuration': None,
#    'total_items_count': 31,
#    'about': '',
#    'verification': {'email': {'valid': True, 'available': True},
#     'facebook': {'valid': True,
#      'verified_at': '2017-12-26T17:43:44+01:00',
#      'available': True,
#      'friend_count': 572},
#     'google': {'valid': False, 'verified_at': None, 'available': True},
#     'phone': {'valid': True,
#      'verified_at': '2018-01-06T00:28:13+01:00',
#      'available': True}},
#    'closet_promoted_until': None,
#    'avg_response_time': None,
#    'carrier_ids': [20, 27, 50, 4, 3, 9, 10],
#    'carriers_without_custom_ids': [20, 27, 50, 4, 3],
#    'updated_on': 1606137864,
#    'is_hated': False,
#    'hates_you': False,
#    'is_favourite': False,
#    'profile_url': 'https://www.vinted.fr/member/14869438-meg69400',
#    'facebook_user_id': None,
#    'is_online': False,
#    'has_promoted_closet': False,
#    'can_view_profile': True,
#    'can_bundle': True,
#    'last_loged_on': "aujourd'hui 10:34",
#    'accepted_pay_in_methods': [{'id': 1,
#      'code': 'CREDIT_CARD',
#      'requires_credit_card': True,
#      'event_tracking_code': 'cc',
#      'icon': 'credit-card',
#      'enabled': True,
#      'translated_name': 'Carte bancaire',
#      'note': "Les informations liées à ta carte bancaire ne seront pas partagées avec le vendeur. Vinted n'enregistre pas tes informations bancaires sans ton autorisation."},
#     {'id': 4,
#      'code': 'SOFORT',
#      'requires_credit_card': False,
#      'event_tracking_code': 'sofort',
#      'icon': 'sofort',
#      'enabled': True,
#      'translated_name': 'Sofort',
#      'note': ''},
#     {'id': 16,
#      'code': 'APPLE_PAY',
#      'requires_credit_card': False,
#      'event_tracking_code': 'apple_pay',
#      'icon': 'apple-pay',
#      'enabled': True,
#      'translated_name': 'Apple Pay',
#      'note': ''},
#     {'id': 10,
#      'code': 'MANGOPAY_PAYPAL',
#      'requires_credit_card': False,
#      'event_tracking_code': 'mangopay_paypal',
#      'icon': 'paypal',
#      'enabled': True,
#      'translated_name': 'PayPal',
#      'note': ''},
#     {'id': 9,
#      'code': 'IDEAL',
#      'requires_credit_card': False,
#      'event_tracking_code': 'ideal',
#      'icon': 'ideal',
#      'enabled': True,
#      'translated_name': 'iDeal',
#      'note': ''}],
#    'localization': 'manual'},
#   'can_edit': False,
#   'can_delete': False,
#   'can_request_reservation': False,
#   'can_cancel_reservation_request': False,
#   'can_reserve': False,
#   'can_transfer': False,
#   'instant_buy': True,
#   'can_close': False,
#   'can_buy': True,
#   'can_bundle': True,
#   'can_ask_seller': True,
#   'can_favourite': False,
#   'user_login': 'meg69400',
#   'city_id': 79124,
#   'city': 'Gleizé',
#   'country': 'France',
#   'nearby': None,
#   'distance': None,
#   'promoted': True,
#   'is_favourite': False,
#   'is_mobile': False,
#   'bump_badge_visible': False,
#   'brand_dto': {'id': 174100,
#    'title': 'Obaïbi',
#    'slug': 'obaibi',
#    'favourite_count': 6261,
#    'pretty_favourite_count': '6.3K',
#    'item_count': 875504,
#    'pretty_item_count': '875.5K',
#    'is_visible_in_listings': True,
#    'path': '/brand/obaibi',
#    'requires_authenticity_check': False,
#    'url': 'https://www.vinted.fr/brand/obaibi',
#    'is_favourite': False,
#    'is_hated': False},
#   'url': 'https://www.vinted.fr/enfants/bebe-filles-ensembles/745337744-vends-ensemble-obaibi-18-m-neuf',
#   'accepted_pay_in_methods': [{'id': 1,
#     'code': 'CREDIT_CARD',
#     'requires_credit_card': True,
#     'event_tracking_code': 'cc',
#     'icon': 'credit-card',
#     'enabled': True,
#     'translated_name': 'Carte bancaire',
#     'note': "Les informations liées à ta carte bancaire ne seront pas partagées avec le vendeur. Vinted n'enregistre pas tes informations bancaires sans ton autorisation."},
#    {'id': 10,
#     'code': 'MANGOPAY_PAYPAL',
#     'requires_credit_card': False,
#     'event_tracking_code': 'mangopay_paypal',
#     'icon': 'paypal',
#     'enabled': True,
#     'translated_name': 'PayPal',
#     'note': ''}],
#   'created_at': '18/11 16:53',
#   'color1': 'Blanc',
#   'color2': 'Marine',
#   'material': None,
#   'status': 'Neuf avec étiquette',
#   'secure_purchase': True,
#   'performance': None,
#   'stats_visible': True,
#   'can_push_up': False,
#   'price': '30,00 €',
#   'discount_price': '',
#   'real_value': '',
#   'size_guide_faq_entry_id': 516,
#   'localization': 'manual'},
#  {'id': 758354364,
#   'title': 'Poupée Midge, amie de Barbie- année 1985- TB état',
#   'brand_id': 263944,
#   'size_id': 620,
#   'status_id': 2,
#   'disposal_conditions': 4,
#   'user_id': 12357599,
#   'owner_id': None,
#   'country_id': 16,
#   'catalog_id': 1731,
#   'color1_id': None,
#   'color2_id': None,
#   'package_size_id': 1,
#   'is_hidden': 0,
#   'is_reserved': 0,
#   'reserved_for_user_id': None,
#   'is_visible': 1,
#   'is_unisex': 0,
#   'is_closed': 0,
#   'is_admin_alerted': False,
#   'active_bid_count': 0,
#   'favourite_count': 2,
#   'view_count': 17,
#   'moderation_status': 0,
#   'last_push_up_at': '2020-11-23T12:18:48+01:00',
#   'description': 'Poupée Midge, amie de Barbie- année 1985- TB état',
#   'package_size_standard': True,
#   'item_closing_action': None,
#   'related_catalog_ids': [],
#   'related_catalogs_enabled': False,
#   'size': 'Taille unique',
#   'brand': 'Mattel',
#   'composition': '',
#   'extra_conditions': '',
#   'is_for_sell': True,
#   'is_for_swap': False,
#   'is_for_give_away': False,
#   'is_handicraft': False,
#   'is_draft': False,
#   'label': 'Mattel',
#   'real_value_numeric': None,
#   'original_price_numeric': '19.0',
#   'price_numeric': '19.0',
#   'currency': '€',
#   'created_at_ts': '2020-11-23T11:17:18+01:00',
#   'updated_at_ts': '2020-11-24T12:20:02+01:00',
#   'user_updated_at_ts': '2020-11-24T12:20:02+01:00',
#   'photos': [{'id': 2652663612,
#     'image_no': 1,
#     'width': 600,
#     'height': 800,
#     'dominant_color': '#757986',
#     'dominant_color_opaque': '#D6D7DB',
#     'url': 'https://images.vinted.net/thumbs/f800/02_00a90_MVQiTUYAE2ziHHwnFxMceYb8.jpeg?1606126641-9f4355ba68b614023f036347da6be8a345c9fa77',
#     'is_main': True,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_00a90_MVQiTUYAE2ziHHwnFxMceYb8.jpeg?1606126641-bab309c6a6b0c93cf01fd7289b80bf2afc5e98b2',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_00a90_MVQiTUYAE2ziHHwnFxMceYb8.jpeg?1606126641-fb3afeaad54e9fc2c426d1514706b7e48a5351cb',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_00a90_MVQiTUYAE2ziHHwnFxMceYb8.jpeg?1606126641-27def958680d1c746a908f25fbaa5c669d1a141c',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_00a90_MVQiTUYAE2ziHHwnFxMceYb8.jpeg?1606126641-9f4355ba68b614023f036347da6be8a345c9fa77',
#       'width': 321,
#       'height': 428,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_00a90_MVQiTUYAE2ziHHwnFxMceYb8.jpeg?1606126641-9f4355ba68b614023f036347da6be8a345c9fa77',
#       'width': 468,
#       'height': 624,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_00a90_MVQiTUYAE2ziHHwnFxMceYb8.jpeg?1606126641-9f4355ba68b614023f036347da6be8a345c9fa77',
#       'width': 273,
#       'height': 364,
#       'original_size': True}],
#     'high_resolution': {'id': '02_00a90_MVQiTUYAE2ziHHwnFxMceYb8',
#      'timestamp': 1606126641,
#      'orientation': 0},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_00a90_MVQiTUYAE2ziHHwnFxMceYb8.jpeg?1606126641-f2a0417a25f5631d3cf765ff6630b4ec9c4b589c'},
#    {'id': 2652724554,
#     'image_no': 2,
#     'width': 800,
#     'height': 600,
#     'dominant_color': '#7F6F69',
#     'dominant_color_opaque': '#D9D4D2',
#     'url': 'https://images.vinted.net/thumbs/f800/02_018ac_xbivE4bNBe9Q1yqXG58nEgLF.jpeg?1606126799-d368ee36a551dc584c02a21ba4152c17e991ea80',
#     'is_main': False,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_018ac_xbivE4bNBe9Q1yqXG58nEgLF.jpeg?1606126799-7ddf0ba98e883d99f10408fe8759c6bc9325bed9',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_018ac_xbivE4bNBe9Q1yqXG58nEgLF.jpeg?1606126799-7ade019ee45042bbff1d6648dbb7ed73fdbb8101',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_018ac_xbivE4bNBe9Q1yqXG58nEgLF.jpeg?1606126799-a0bf7907ebfdd94a3bf6b20d66abad23c301af1b',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_018ac_xbivE4bNBe9Q1yqXG58nEgLF.jpeg?1606126799-d368ee36a551dc584c02a21ba4152c17e991ea80',
#       'width': 428,
#       'height': 321,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_018ac_xbivE4bNBe9Q1yqXG58nEgLF.jpeg?1606126799-d368ee36a551dc584c02a21ba4152c17e991ea80',
#       'width': 624,
#       'height': 468,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_018ac_xbivE4bNBe9Q1yqXG58nEgLF.jpeg?1606126799-d368ee36a551dc584c02a21ba4152c17e991ea80',
#       'width': 364,
#       'height': 273,
#       'original_size': True}],
#     'high_resolution': {'id': '02_018ac_xbivE4bNBe9Q1yqXG58nEgLF',
#      'timestamp': 1606126799,
#      'orientation': 0},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_018ac_xbivE4bNBe9Q1yqXG58nEgLF.jpeg?1606126799-084750c58bf04abcc03184df5f346dbe8cc717da'}],
#   'push_up_interval': 604800,
#   'can_be_sold': True,
#   'can_feedback': False,
#   'path': '/enfants/poupees/758354364-poupee-midge-amie-de-barbie-annee-1985-tb-etat',
#   'possible_to_request_reservation': True,
#   'item_reservation_id': None,
#   'receiver_id': None,
#   'promoted_until': '2020-11-30T12:18:48+01:00',
#   'discount_price_numeric': None,
#   'badge': None,
#   'reservation_requests_from_users': [],
#   'material_id': None,
#   'author': None,
#   'book_title': None,
#   'isbn': None,
#   'defect_ids': [],
#   'user': {'id': 12357599,
#    'anon_id': 'ea02e5af-1f32-4788-90c5-3519a8898637',
#    'login': 'angevine58',
#    'real_name': None,
#    'email': None,
#    'birthday': None,
#    'gender': 'F',
#    'item_count': 124,
#    'msg_template_count': 2,
#    'given_item_count': 25,
#    'taken_item_count': 17,
#    'favourite_topic_count': 0,
#    'forum_msg_count': 0,
#    'forum_topic_count': 0,
#    'followers_count': 17,
#    'following_count': 1,
#    'following_brands_count': 0,
#    'positive_feedback_count': 24,
#    'neutral_feedback_count': 0,
#    'negative_feedback_count': 0,
#    'meeting_transaction_count': 0,
#    'account_status': 0,
#    'email_bounces': None,
#    'feedback_reputation': 1.0,
#    'account_ban_date': None,
#    'forum_ban_date': None,
#    'is_on_holiday': False,
#    'is_publish_photos_agreed': True,
#    'is_shadow_banned': False,
#    'is_identity': False,
#    'expose_location': True,
#    'third_party_tracking': True,
#    'default_address': None,
#    'created_at': '2017-03-02T19:05:14+01:00',
#    'last_loged_on_ts': '2020-11-24T12:10:26+01:00',
#    'city_id': 14606,
#    'city': 'Angers',
#    'country_id': 16,
#    'country_code': 'FR',
#    'country_title_local': 'France',
#    'country_title': 'France',
#    'contacts_permission': None,
#    'contacts': None,
#    'photo': {'id': 22661991,
#     'width': 527,
#     'height': 527,
#     'temp_uuid': None,
#     'url': 'https://images.vinted.net/thumbs/f800/02_019a6_PjUAdVgDiA4LPpVaRmGvuBCe.jpeg?1605242849-1178263d1b3032989b035349e15d61377db7e8db',
#     'dominant_color': '#31abc2',
#     'dominant_color_opaque': '#C1E6ED',
#     'thumbnails': [{'type': 'thumb310',
#       'url': 'https://images.vinted.net/thumbs/310x310/02_019a6_PjUAdVgDiA4LPpVaRmGvuBCe.jpeg?1605242849-aecdd3364a82e53094d20ab839d0e9671f53afe3',
#       'width': 310,
#       'height': 310,
#       'original_size': None},
#      {'type': 'thumb150',
#       'url': 'https://images.vinted.net/thumbs/150x150/02_019a6_PjUAdVgDiA4LPpVaRmGvuBCe.jpeg?1605242849-9e162acc1e587b77a8db6e394babaf2e5900baee',
#       'width': 150,
#       'height': 150,
#       'original_size': None},
#      {'type': 'thumb100',
#       'url': 'https://images.vinted.net/thumbs/100x100/02_019a6_PjUAdVgDiA4LPpVaRmGvuBCe.jpeg?1605242849-c0a504658ac9cf3e732b7aec46134c2ea7075bd3',
#       'width': 100,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb50',
#       'url': 'https://images.vinted.net/thumbs/50x50/02_019a6_PjUAdVgDiA4LPpVaRmGvuBCe.jpeg?1605242849-29254f4c83be44e06692fc8bf2ebd6fada0d935f',
#       'width': 50,
#       'height': 50,
#       'original_size': None},
#      {'type': 'thumb20',
#       'url': 'https://images.vinted.net/thumbs/20x20/02_019a6_PjUAdVgDiA4LPpVaRmGvuBCe.jpeg?1605242849-da7dc2de5fda40f6d859136afc3ab9abb2742c1b',
#       'width': 20,
#       'height': 20,
#       'original_size': None}],
#     'is_suspicious': False,
#     'orientation': None,
#     'high_resolution': {'id': '02_019a6_PjUAdVgDiA4LPpVaRmGvuBCe',
#      'timestamp': 1605242849,
#      'orientation': None},
#     'full_size_url': 'https://images.vinted.net/thumbs/02_019a6_PjUAdVgDiA4LPpVaRmGvuBCe.jpeg?1605242849-ebd9146f18e59428d4c1937d8d8a373ee470abe1'},
#    'path': '/member/12357599-angevine58',
#    'is_god': False,
#    'is_tester': False,
#    'moderator': False,
#    'volunteer_moderator': False,
#    'hide_feedback': False,
#    'can_post_big_forum_photos': False,
#    'allow_direct_messaging': True,
#    'bundle_discount': {'id': 4584533,
#     'user_id': 12357599,
#     'enabled': True,
#     'minimal_item_count': 2,
#     'fraction': '0.05',
#     'discounts': [{'minimal_item_count': 2, 'fraction': '0.05'},
#      {'minimal_item_count': 3, 'fraction': '0.1'},
#      {'minimal_item_count': 5, 'fraction': '0.15'}]},
#    'donation_configuration': None,
#    'total_items_count': 149,
#    'about': '',
#    'verification': {'email': {'valid': True, 'available': True},
#     'facebook': {'valid': True,
#      'verified_at': '2019-10-14T18:49:36+02:00',
#      'available': True,
#      'friend_count': None},
#     'google': {'valid': False, 'verified_at': None, 'available': True},
#     'phone': {'valid': True,
#      'verified_at': '2019-04-24T11:45:37+02:00',
#      'available': True}},
#    'closet_promoted_until': '2020-11-29T13:28:22+01:00',
#    'avg_response_time': None,
#    'carrier_ids': [20, 27, 50, 4, 3, 9, 10],
#    'carriers_without_custom_ids': [20, 27, 50, 4, 3],
#    'updated_on': 1606204280,
#    'is_hated': False,
#    'hates_you': False,
#    'is_favourite': False,
#    'profile_url': 'https://www.vinted.fr/member/12357599-angevine58',
#    'facebook_user_id': None,
#    'is_online': False,
#    'has_promoted_closet': True,
#    'can_view_profile': True,
#    'can_bundle': True,
#    'last_loged_on': "aujourd'hui 12:10",
#    'accepted_pay_in_methods': [{'id': 1,
#      'code': 'CREDIT_CARD',
#      'requires_credit_card': True,
#      'event_tracking_code': 'cc',
#      'icon': 'credit-card',
#      'enabled': True,
#      'translated_name': 'Carte bancaire',
#      'note': "Les informations liées à ta carte bancaire ne seront pas partagées avec le vendeur. Vinted n'enregistre pas tes informations bancaires sans ton autorisation."},
#     {'id': 4,
#      'code': 'SOFORT',
#      'requires_credit_card': False,
#      'event_tracking_code': 'sofort',
#      'icon': 'sofort',
#      'enabled': True,
#      'translated_name': 'Sofort',
#      'note': ''},
#     {'id': 16,
#      'code': 'APPLE_PAY',
#      'requires_credit_card': False,
#      'event_tracking_code': 'apple_pay',
#      'icon': 'apple-pay',
#      'enabled': True,
#      'translated_name': 'Apple Pay',
#      'note': ''},
#     {'id': 10,
#      'code': 'MANGOPAY_PAYPAL',
#      'requires_credit_card': False,
#      'event_tracking_code': 'mangopay_paypal',
#      'icon': 'paypal',
#      'enabled': True,
#      'translated_name': 'PayPal',
#      'note': ''},
#     {'id': 9,
#      'code': 'IDEAL',
#      'requires_credit_card': False,
#      'event_tracking_code': 'ideal',
#      'icon': 'ideal',
#      'enabled': True,
#      'translated_name': 'iDeal',
#      'note': ''}],
#    'localization': 'manual'},
#   'can_edit': False,
#   'can_delete': False,
#   'can_request_reservation': False,
#   'can_cancel_reservation_request': False,
#   'can_reserve': False,
#   'can_transfer': False,
#   'instant_buy': True,
#   'can_close': False,
#   'can_buy': True,
#   'can_bundle': True,
#   'can_ask_seller': True,
#   'can_favourite': False,
#   'user_login': 'angevine58',
#   'city_id': 14606,
#   'city': 'Angers',
#   'country': 'France',
#   'nearby': None,
#   'distance': None,
#   'promoted': True,
#   'is_favourite': False,
#   'is_mobile': False,
#   'bump_badge_visible': False,
#   'brand_dto': {'id': 263944,
#    'title': 'Mattel',
#    'slug': 'mattel',
#    'favourite_count': 1343,
#    'pretty_favourite_count': '1.3K',
#    'item_count': 87380,
#    'pretty_item_count': '87.4K',
#    'is_visible_in_listings': True,
#    'path': '/brand/mattel',
#    'requires_authenticity_check': False,
#    'url': 'https://www.vinted.fr/brand/mattel',
#    'is_favourite': False,
#    'is_hated': False},
#   'url': 'https://www.vinted.fr/enfants/poupees/758354364-poupee-midge-amie-de-barbie-annee-1985-tb-etat',
#   'accepted_pay_in_methods': [{'id': 1,
#     'code': 'CREDIT_CARD',
#     'requires_credit_card': True,
#     'event_tracking_code': 'cc',
#     'icon': 'credit-card',
#     'enabled': True,
#     'translated_name': 'Carte bancaire',
#     'note': "Les informations liées à ta carte bancaire ne seront pas partagées avec le vendeur. Vinted n'enregistre pas tes informations bancaires sans ton autorisation."},
#    {'id': 10,
#     'code': 'MANGOPAY_PAYPAL',
#     'requires_credit_card': False,
#     'event_tracking_code': 'mangopay_paypal',
#     'icon': 'paypal',
#     'enabled': True,
#     'translated_name': 'PayPal',
#     'note': ''}],
#   'created_at': 'hier 11:17',
#   'color1': None,
#   'color2': None,
#   'material': None,
#   'status': 'Très bon état',
#   'secure_purchase': True,
#   'performance': None,
#   'stats_visible': True,
#   'can_push_up': False,
#   'price': '19,00 €',
#   'discount_price': '',
#   'real_value': '',
#   'size_guide_faq_entry_id': 516,
#   'localization': 'manual'},
#  {'id': 736114411,
#   'title': 'Pakket jongens jassen,  winterjas,  zomerjas,  regenjas,  vest 122, 128, 134',
#   'brand_id': 2383,
#   'size_id': 627,
#   'status_id': 2,
#   'disposal_conditions': 4,
#   'user_id': 44907968,
#   'owner_id': None,
#   'country_id': 10,
#   'catalog_id': 1647,
#   'color1_id': 9,
#   'color2_id': None,
#   'package_size_id': 4,
#   'is_hidden': 0,
#   'is_reserved': 0,
#   'reserved_for_user_id': None,
#   'is_visible': 1,
#   'is_unisex': 0,
#   'is_closed': 0,
#   'is_admin_alerted': True,
#   'active_bid_count': 2,
#   'favourite_count': 1,
#   'view_count': 69,
#   'moderation_status': 0,
#   'last_push_up_at': '2020-11-23T12:19:45+01:00',
#   'description': 'Mooi pakket jongens jassen, zowel zomer als winter als regen. De middelste twee zijn nieuw de andere vier in zeer goede staat. Graag bieden naar waarde, dit mag uiteraard ook per stuk.',
#   'package_size_standard': False,
#   'item_closing_action': None,
#   'related_catalog_ids': [],
#   'related_catalogs_enabled': False,
#   'size': '8 ans / 122-128 cm',
#   'brand': 'CoolCat',
#   'composition': '',
#   'extra_conditions': '',
#   'is_for_sell': True,
#   'is_for_swap': False,
#   'is_for_give_away': False,
#   'is_handicraft': False,
#   'is_draft': False,
#   'label': 'CoolCat',
#   'real_value_numeric': None,
#   'original_price_numeric': '70.0',
#   'price_numeric': '70.0',
#   'currency': '€',
#   'shipment_prices': {'domestic': '4.5'},
#   'custom_shipment_price': '4.5',
#   'created_at_ts': '2020-11-16T06:43:52+01:00',
#   'updated_at_ts': '2020-11-24T12:20:02+01:00',
#   'user_updated_at_ts': '2020-11-24T12:20:02+01:00',
#   'photos': [{'id': 2573616263,
#     'image_no': 1,
#     'width': 800,
#     'height': 800,
#     'dominant_color': '#646C72',
#     'dominant_color_opaque': '#D1D3D5',
#     'url': 'https://images.vinted.net/thumbs/f800/02_02042_8NU43GbpAK8pwikSHFb2XUBv.jpeg?1605505432-260b25c1c38c7eb95df885930236d8fb3235d2f9',
#     'is_main': True,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_02042_8NU43GbpAK8pwikSHFb2XUBv.jpeg?1605505432-a9ae764d92de3fe896bed2127f235596817b1675',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_02042_8NU43GbpAK8pwikSHFb2XUBv.jpeg?1605505432-0bc849779f00ebfa7aaed1809d7607b383dc44f6',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_02042_8NU43GbpAK8pwikSHFb2XUBv.jpeg?1605505432-1b54bd4c89c7f71b01fa03ec84d4734780f65fe3',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_02042_8NU43GbpAK8pwikSHFb2XUBv.jpeg?1605505432-260b25c1c38c7eb95df885930236d8fb3235d2f9',
#       'width': 428,
#       'height': 428,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_02042_8NU43GbpAK8pwikSHFb2XUBv.jpeg?1605505432-260b25c1c38c7eb95df885930236d8fb3235d2f9',
#       'width': 624,
#       'height': 624,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_02042_8NU43GbpAK8pwikSHFb2XUBv.jpeg?1605505432-260b25c1c38c7eb95df885930236d8fb3235d2f9',
#       'width': 364,
#       'height': 364,
#       'original_size': True}],
#     'high_resolution': {'id': '02_02042_8NU43GbpAK8pwikSHFb2XUBv',
#      'timestamp': 1605505432,
#      'orientation': None},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_02042_8NU43GbpAK8pwikSHFb2XUBv.jpeg?1605505432-1f8c5e1ec9d03d5431f5be57cd3f0e3f1f96b3ef'},
#    {'id': 2573616267,
#     'image_no': 2,
#     'width': 600,
#     'height': 800,
#     'dominant_color': '#453B42',
#     'dominant_color_opaque': '#C7C4C6',
#     'url': 'https://images.vinted.net/thumbs/f800/02_01990_TADqFMW9aJdiEwHvDwPSteGs.jpeg?1605505432-ae8580e78125a4d58f069d90e2e47673c2f6fd75',
#     'is_main': False,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_01990_TADqFMW9aJdiEwHvDwPSteGs.jpeg?1605505432-364d01185d6ee1441b2c002bd276febf81588c8e',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_01990_TADqFMW9aJdiEwHvDwPSteGs.jpeg?1605505432-7d1d94380d0784373062d368eb8765734979c4d9',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_01990_TADqFMW9aJdiEwHvDwPSteGs.jpeg?1605505432-df329241ab2e8e051842c29d27246be9fc984a79',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_01990_TADqFMW9aJdiEwHvDwPSteGs.jpeg?1605505432-ae8580e78125a4d58f069d90e2e47673c2f6fd75',
#       'width': 321,
#       'height': 428,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_01990_TADqFMW9aJdiEwHvDwPSteGs.jpeg?1605505432-ae8580e78125a4d58f069d90e2e47673c2f6fd75',
#       'width': 468,
#       'height': 624,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_01990_TADqFMW9aJdiEwHvDwPSteGs.jpeg?1605505432-ae8580e78125a4d58f069d90e2e47673c2f6fd75',
#       'width': 273,
#       'height': 364,
#       'original_size': True}],
#     'high_resolution': {'id': '02_01990_TADqFMW9aJdiEwHvDwPSteGs',
#      'timestamp': 1605505432,
#      'orientation': None},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_01990_TADqFMW9aJdiEwHvDwPSteGs.jpeg?1605505432-6baf0a20eba57ddfa766e9863fa076415a73d62b'},
#    {'id': 2573616258,
#     'image_no': 3,
#     'width': 600,
#     'height': 800,
#     'dominant_color': '#1968A3',
#     'dominant_color_opaque': '#BAD2E3',
#     'url': 'https://images.vinted.net/thumbs/f800/02_013f1_CYy9ThMhmgGbty7pW6GpJfFu.jpeg?1605505432-94a6cf68b9b9f7244bf9258817032ee16ffc3af4',
#     'is_main': False,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_013f1_CYy9ThMhmgGbty7pW6GpJfFu.jpeg?1605505432-1df30a525536311fecf8b2c41192556758c29c01',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_013f1_CYy9ThMhmgGbty7pW6GpJfFu.jpeg?1605505432-0216bc6a097a0e49cba7319f9e506b16d07e7707',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_013f1_CYy9ThMhmgGbty7pW6GpJfFu.jpeg?1605505432-871a0872245eecc67b431937f9187983c79782d2',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_013f1_CYy9ThMhmgGbty7pW6GpJfFu.jpeg?1605505432-94a6cf68b9b9f7244bf9258817032ee16ffc3af4',
#       'width': 321,
#       'height': 428,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_013f1_CYy9ThMhmgGbty7pW6GpJfFu.jpeg?1605505432-94a6cf68b9b9f7244bf9258817032ee16ffc3af4',
#       'width': 468,
#       'height': 624,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_013f1_CYy9ThMhmgGbty7pW6GpJfFu.jpeg?1605505432-94a6cf68b9b9f7244bf9258817032ee16ffc3af4',
#       'width': 273,
#       'height': 364,
#       'original_size': True}],
#     'high_resolution': {'id': '02_013f1_CYy9ThMhmgGbty7pW6GpJfFu',
#      'timestamp': 1605505432,
#      'orientation': None},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_013f1_CYy9ThMhmgGbty7pW6GpJfFu.jpeg?1605505432-611008648f12195c856a9056eb6cdbfe636f6b1f'},
#    {'id': 2573616257,
#     'image_no': 4,
#     'width': 600,
#     'height': 800,
#     'dominant_color': '#4A3E39',
#     'dominant_color_opaque': '#C9C5C4',
#     'url': 'https://images.vinted.net/thumbs/f800/02_01180_1uMkv1jxzc2XtxtMv1q13ZHX.jpeg?1605505432-d5f728fa9d77ebaacc9f2fa791d0cdb5fadc5da0',
#     'is_main': False,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_01180_1uMkv1jxzc2XtxtMv1q13ZHX.jpeg?1605505432-3d9f0917f4925ef414095fab18bd6337df4e6af9',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_01180_1uMkv1jxzc2XtxtMv1q13ZHX.jpeg?1605505432-ecdafbaae153b33d1931b0b5af9ad95c3d3ee3fe',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_01180_1uMkv1jxzc2XtxtMv1q13ZHX.jpeg?1605505432-f9f5a7723152686eab8e392f539dbeff6602842e',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_01180_1uMkv1jxzc2XtxtMv1q13ZHX.jpeg?1605505432-d5f728fa9d77ebaacc9f2fa791d0cdb5fadc5da0',
#       'width': 321,
#       'height': 428,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_01180_1uMkv1jxzc2XtxtMv1q13ZHX.jpeg?1605505432-d5f728fa9d77ebaacc9f2fa791d0cdb5fadc5da0',
#       'width': 468,
#       'height': 624,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_01180_1uMkv1jxzc2XtxtMv1q13ZHX.jpeg?1605505432-d5f728fa9d77ebaacc9f2fa791d0cdb5fadc5da0',
#       'width': 273,
#       'height': 364,
#       'original_size': True}],
#     'high_resolution': {'id': '02_01180_1uMkv1jxzc2XtxtMv1q13ZHX',
#      'timestamp': 1605505432,
#      'orientation': None},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_01180_1uMkv1jxzc2XtxtMv1q13ZHX.jpeg?1605505432-aa237f439d638c356b25f1fc9f3fcb5356b258a5'},
#    {'id': 2573616273,
#     'image_no': 5,
#     'width': 600,
#     'height': 800,
#     'dominant_color': '#494E52',
#     'dominant_color_opaque': '#C8CACB',
#     'url': 'https://images.vinted.net/thumbs/f800/02_01ede_o2zJK3VQgZbRc1p6kqYVCvSb.jpeg?1605505432-b55379d1636fb3af9a039fef7dcfec3524b41c45',
#     'is_main': False,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_01ede_o2zJK3VQgZbRc1p6kqYVCvSb.jpeg?1605505432-29fe4d9b120a8aef706ef7c7b6ec6031e1906c70',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_01ede_o2zJK3VQgZbRc1p6kqYVCvSb.jpeg?1605505432-54db2a15fb8e2906250f923cfee8713826eb7405',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_01ede_o2zJK3VQgZbRc1p6kqYVCvSb.jpeg?1605505432-3bbb6ed603d2c775ebb86dbdfd09adef44377fa8',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_01ede_o2zJK3VQgZbRc1p6kqYVCvSb.jpeg?1605505432-b55379d1636fb3af9a039fef7dcfec3524b41c45',
#       'width': 321,
#       'height': 428,
#       'original_size': True},
#      {'type': 'thumb624x428',
# ...
#    'donation_configuration': None,
#    'total_items_count': 10,
#    'about': '',
#    'verification': {'email': {'valid': True, 'available': True},
#     'facebook': {'valid': False,
#      'verified_at': None,
#      'available': True,
#      'friend_count': None},
#     'google': {'valid': False, 'verified_at': None, 'available': True},
#     'phone': {'valid': False, 'verified_at': None, 'available': True}},
#    'closet_promoted_until': None,
#    'avg_response_time': None,
#    'carrier_ids': [21, 22, 36, 4, 9, 10],
#    'carriers_without_custom_ids': [21, 22, 36, 4],
#    'updated_on': 1606164717,
#    'is_hated': False,
#    'hates_you': False,
#    'is_favourite': False,
#    'profile_url': 'https://www.vinted.fr/member/44789413-sophiecloset',
#    'facebook_user_id': None,
#    'is_online': False,
#    'has_promoted_closet': False,
#    'can_view_profile': True,
#    'can_bundle': True,
#    'last_loged_on': 'hier 23:46',
#    'accepted_pay_in_methods': [{'id': 1,
#      'code': 'CREDIT_CARD',
#      'requires_credit_card': True,
#      'event_tracking_code': 'cc',
#      'icon': 'credit-card',
#      'enabled': True,
#      'translated_name': 'Carte bancaire',
#      'note': "Les informations liées à ta carte bancaire ne seront pas partagées avec le vendeur. Vinted n'enregistre pas tes informations bancaires sans ton autorisation."},
#     {'id': 4,
#      'code': 'SOFORT',
#      'requires_credit_card': False,
#      'event_tracking_code': 'sofort',
#      'icon': 'sofort',
#      'enabled': True,
#      'translated_name': 'Sofort',
#      'note': ''},
#     {'id': 16,
#      'code': 'APPLE_PAY',
#      'requires_credit_card': False,
#      'event_tracking_code': 'apple_pay',
#      'icon': 'apple-pay',
#      'enabled': True,
#      'translated_name': 'Apple Pay',
#      'note': ''},
#     {'id': 10,
#      'code': 'MANGOPAY_PAYPAL',
#      'requires_credit_card': False,
#      'event_tracking_code': 'mangopay_paypal',
#      'icon': 'paypal',
#      'enabled': True,
#      'translated_name': 'PayPal',
#      'note': ''},
#     {'id': 9,
#      'code': 'IDEAL',
#      'requires_credit_card': False,
#      'event_tracking_code': 'ideal',
#      'icon': 'ideal',
#      'enabled': True,
#      'translated_name': 'iDeal',
#      'note': ''}],
#    'localization': 'manual'},
#   'can_edit': False,
#   'can_delete': False,
#   'can_request_reservation': False,
#   'can_cancel_reservation_request': False,
#   'can_reserve': False,
#   'can_transfer': False,
#   'instant_buy': True,
#   'can_close': False,
#   'can_buy': True,
#   'can_bundle': True,
#   'can_ask_seller': True,
#   'can_favourite': False,
#   'user_login': 'sophie.closet',
#   'city_id': 110263,
#   'city': 'Pellenberg',
#   'country': 'België',
#   'nearby': None,
#   'distance': None,
#   'promoted': True,
#   'is_favourite': False,
#   'is_mobile': False,
#   'bump_badge_visible': False,
#   'brand_dto': {'id': 16357,
#    'title': 'Marella',
#    'slug': 'marella',
#    'favourite_count': 1765,
#    'pretty_favourite_count': '1.8K',
#    'item_count': 7121,
#    'pretty_item_count': '7.1K',
#    'is_visible_in_listings': True,
#    'path': '/brand/marella',
#    'requires_authenticity_check': False,
#    'url': 'https://www.vinted.fr/brand/marella',
#    'is_favourite': False,
#    'is_hated': False},
#   'url': 'https://www.vinted.fr/enfants/vetements-dexterieur-ponchos/733715330-ponscho-van-marella',
#   'accepted_pay_in_methods': [{'id': 1,
#     'code': 'CREDIT_CARD',
#     'requires_credit_card': True,
#     'event_tracking_code': 'cc',
#     'icon': 'credit-card',
#     'enabled': True,
#     'translated_name': 'Carte bancaire',
#     'note': "Les informations liées à ta carte bancaire ne seront pas partagées avec le vendeur. Vinted n'enregistre pas tes informations bancaires sans ton autorisation."},
#    {'id': 10,
#     'code': 'MANGOPAY_PAYPAL',
#     'requires_credit_card': False,
#     'event_tracking_code': 'mangopay_paypal',
#     'icon': 'paypal',
#     'enabled': True,
#     'translated_name': 'PayPal',
#     'note': ''}],
#   'created_at': '15/11 16:20',
#   'color1': 'Gris',
#   'color2': None,
#   'material': None,
#   'status': 'Très bon état',
#   'secure_purchase': True,
#   'performance': None,
#   'stats_visible': True,
#   'can_push_up': False,
#   'price': '20,00 €',
#   'discount_price': '',
#   'real_value': '',
#   'size_guide_faq_entry_id': 516,
#   'localization': 'manual'},
#  {'id': 749000227,
#   'title': 'Bop-it! Tetris',
#   'brand_id': 114196,
#   'size_id': 620,
#   'status_id': 3,
#   'disposal_conditions': 4,
#   'user_id': 45514452,
#   'owner_id': None,
#   'country_id': 19,
#   'catalog_id': 1725,
#   'color1_id': None,
#   'color2_id': None,
#   'package_size_id': 1,
#   'is_hidden': 0,
#   'is_reserved': 0,
#   'reserved_for_user_id': None,
#   'is_visible': 1,
#   'is_unisex': 0,
#   'is_closed': 0,
#   'is_admin_alerted': False,
#   'active_bid_count': 0,
#   'favourite_count': 0,
#   'view_count': 42,
#   'moderation_status': 0,
#   'last_push_up_at': '2020-11-22T12:14:14+01:00',
#   'description': 'leuk om alleen of samen te spelen.',
#   'package_size_standard': True,
#   'item_closing_action': None,
#   'related_catalog_ids': [],
#   'related_catalogs_enabled': False,
#   'size': 'Taille unique',
#   'brand': 'Hasbro',
#   'composition': '',
#   'extra_conditions': '',
#   'is_for_sell': True,
#   'is_for_swap': False,
#   'is_for_give_away': False,
#   'is_handicraft': False,
#   'is_draft': False,
#   'label': 'Hasbro',
#   'real_value_numeric': None,
#   'original_price_numeric': '23.0',
#   'price_numeric': '23.0',
#   'currency': '€',
#   'created_at_ts': '2020-11-19T22:00:59+01:00',
#   'updated_at_ts': '2020-11-24T12:20:02+01:00',
#   'user_updated_at_ts': '2020-11-24T12:20:02+01:00',
#   'photos': [{'id': 2618231286,
#     'image_no': 1,
#     'width': 450,
#     'height': 800,
#     'dominant_color': '#0F0C0B',
#     'dominant_color_opaque': '#B7B6B6',
#     'url': 'https://images.vinted.net/thumbs/f800/02_0257b_riS5SPfgVYJJfxr3ruhBkTqK.jpeg?1605819660-2f779ffc1170a47d9edbfb363ea0a07dc5390d6d',
#     'is_main': True,
#     'thumbnails': [{'type': 'thumb70x100',
#       'url': 'https://images.vinted.net/thumbs/70x100/02_0257b_riS5SPfgVYJJfxr3ruhBkTqK.jpeg?1605819660-ea547f8ce46db662f6b454d9661ef5310cd0a832',
#       'width': 70,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb150x210',
#       'url': 'https://images.vinted.net/thumbs/150x210/02_0257b_riS5SPfgVYJJfxr3ruhBkTqK.jpeg?1605819660-0d2133f321547a437ec9c5b6f9bf736f2ae22030',
#       'width': 150,
#       'height': 210,
#       'original_size': None},
#      {'type': 'thumb310x430',
#       'url': 'https://images.vinted.net/thumbs/310x430/02_0257b_riS5SPfgVYJJfxr3ruhBkTqK.jpeg?1605819660-69e2fcc5e56dad2b28a80398daaa68c214597753',
#       'width': 310,
#       'height': 430,
#       'original_size': None},
#      {'type': 'thumb428x624',
#       'url': 'https://images.vinted.net/thumbs/f800/02_0257b_riS5SPfgVYJJfxr3ruhBkTqK.jpeg?1605819660-2f779ffc1170a47d9edbfb363ea0a07dc5390d6d',
#       'width': 240,
#       'height': 428,
#       'original_size': True},
#      {'type': 'thumb624x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_0257b_riS5SPfgVYJJfxr3ruhBkTqK.jpeg?1605819660-2f779ffc1170a47d9edbfb363ea0a07dc5390d6d',
#       'width': 351,
#       'height': 624,
#       'original_size': True},
#      {'type': 'thumb364x428',
#       'url': 'https://images.vinted.net/thumbs/f800/02_0257b_riS5SPfgVYJJfxr3ruhBkTqK.jpeg?1605819660-2f779ffc1170a47d9edbfb363ea0a07dc5390d6d',
#       'width': 204,
#       'height': 364,
#       'original_size': True}],
#     'high_resolution': {'id': '02_0257b_riS5SPfgVYJJfxr3ruhBkTqK',
#      'timestamp': 1605819660,
#      'orientation': None},
#     'is_suspicious': False,
#     'full_size_url': 'https://images.vinted.net/thumbs/02_0257b_riS5SPfgVYJJfxr3ruhBkTqK.jpeg?1605819660-bceb84bab8ffaebfc5e610361a8ab49cea665ef7'}],
#   'push_up_interval': 604800,
#   'can_be_sold': True,
#   'can_feedback': False,
#   'path': '/enfants/jeux-electroniques/749000227-bop-it-tetris',
#   'possible_to_request_reservation': True,
#   'item_reservation_id': None,
#   'receiver_id': None,
#   'promoted_until': '2020-11-29T12:14:14+01:00',
#   'discount_price_numeric': None,
#   'badge': None,
#   'reservation_requests_from_users': [],
#   'material_id': None,
#   'author': None,
#   'book_title': None,
#   'isbn': None,
#   'defect_ids': [],
#   'user': {'id': 45514452,
#    'anon_id': '6500b296-8df4-4f58-aa47-47513cf7c659',
#    'login': 'milan_knaepen123',
#    'real_name': None,
#    'email': None,
#    'birthday': None,
#    'gender': '',
#    'item_count': 1,
#    'msg_template_count': 0,
#    'given_item_count': 0,
#    'taken_item_count': 0,
#    'favourite_topic_count': 0,
#    'forum_msg_count': 0,
#    'forum_topic_count': 0,
#    'followers_count': 0,
#    'following_count': 0,
#    'following_brands_count': 0,
#    'positive_feedback_count': 0,
#    'neutral_feedback_count': 0,
#    'negative_feedback_count': 0,
#    'meeting_transaction_count': 0,
#    'account_status': 0,
#    'email_bounces': None,
#    'feedback_reputation': 0.0,
#    'account_ban_date': None,
#    'forum_ban_date': None,
#    'is_on_holiday': False,
#    'is_publish_photos_agreed': False,
#    'is_shadow_banned': False,
#    'is_identity': False,
#    'expose_location': True,
#    'third_party_tracking': True,
#    'default_address': None,
#    'created_at': '2020-11-19T21:25:37+01:00',
#    'last_loged_on_ts': '2020-11-22T12:12:40+01:00',
#    'city_id': 83034,
#    'city': 'Herk-de-Stad',
#    'country_id': 19,
#    'country_code': 'BE',
#    'country_title_local': 'Belgique / België',
#    'country_title': 'Belgique',
#    'contacts_permission': None,
#    'contacts': None,
#    'photo': {'id': 40537550,
#     'width': 96,
#     'height': 96,
#     'temp_uuid': None,
#     'url': 'https://images.vinted.net/thumbs/f800/02_014dd_7yyB9o8utoy3gT9ojrhxvTxn.jpeg?1605817538-4526913f7e76828e26cb9d439651fdce198237d4',
#     'dominant_color': '#31abc2',
#     'dominant_color_opaque': '#C1E6ED',
#     'thumbnails': [{'type': 'thumb310',
#       'url': 'https://images.vinted.net/thumbs/310x310/02_014dd_7yyB9o8utoy3gT9ojrhxvTxn.jpeg?1605817538-515570e7216be7fa55a6172c18675af1d9203e6a',
#       'width': 310,
#       'height': 310,
#       'original_size': None},
#      {'type': 'thumb150',
#       'url': 'https://images.vinted.net/thumbs/150x150/02_014dd_7yyB9o8utoy3gT9ojrhxvTxn.jpeg?1605817538-8c0fbce7ae22323c017354616566dcaaadf080ea',
#       'width': 150,
#       'height': 150,
#       'original_size': None},
#      {'type': 'thumb100',
#       'url': 'https://images.vinted.net/thumbs/100x100/02_014dd_7yyB9o8utoy3gT9ojrhxvTxn.jpeg?1605817538-139d46cbb391b631de3de9bd856e99655dd3cf09',
#       'width': 100,
#       'height': 100,
#       'original_size': None},
#      {'type': 'thumb50',
#       'url': 'https://images.vinted.net/thumbs/50x50/02_014dd_7yyB9o8utoy3gT9ojrhxvTxn.jpeg?1605817538-c8fcdb6887bdd9fffa9b6fbe8e8f4c37d13fe6a0',
#       'width': 50,
#       'height': 50,
#       'original_size': None},
#      {'type': 'thumb20',
#       'url': 'https://images.vinted.net/thumbs/20x20/02_014dd_7yyB9o8utoy3gT9ojrhxvTxn.jpeg?1605817538-088909416820c2150a2afba6b799d6c417425ac1',
#       'width': 20,
#       'height': 20,
#       'original_size': None}],
#     'is_suspicious': False,
#     'orientation': None,
#     'high_resolution': {'id': '02_014dd_7yyB9o8utoy3gT9ojrhxvTxn',
#      'timestamp': 1605817538,
#      'orientation': None},
#     'full_size_url': 'https://images.vinted.net/thumbs/02_014dd_7yyB9o8utoy3gT9ojrhxvTxn.jpeg?1605817538-aba8fa374d1b4b8675215f381d0654defd775e7a'},
#    'path': '/member/45514452-milanknaepen123',
#    'is_god': False,
#    'is_tester': False,
#    'moderator': False,
#    'volunteer_moderator': False,
#    'hide_feedback': False,
#    'can_post_big_forum_photos': False,
#    'allow_direct_messaging': True,
#    'bundle_discount': {'id': 7785977,
#     'user_id': 45514452,
#     'enabled': False,
#     'minimal_item_count': 2,
#     'fraction': '0.25',
#     'discounts': [{'minimal_item_count': 2, 'fraction': '0.25'},
#      {'minimal_item_count': 3, 'fraction': '0.3'},
#      {'minimal_item_count': 5, 'fraction': '0.5'}]},
#    'donation_configuration': None,
#    'total_items_count': 1,
#    'about': '',
#    'verification': {'email': {'valid': True, 'available': True},
#     'facebook': {'valid': False,
#      'verified_at': None,
#      'available': True,
#      'friend_count': None},
#     'google': {'valid': True,
#      'verified_at': '2020-11-19T21:25:08+01:00',
#      'available': True},
#     'phone': {'valid': False, 'verified_at': None, 'available': True}},
#    'closet_promoted_until': None,
#    'avg_response_time': None,
#    'carrier_ids': [21, 22, 36, 4, 9, 10],
#    'carriers_without_custom_ids': [21, 22, 36, 4],
#    'updated_on': 1605870591,
#    'is_hated': False,
#    'hates_you': False,
#    'is_favourite': False,
#    'profile_url': 'https://www.vinted.fr/member/45514452-milanknaepen123',
#    'facebook_user_id': None,
#    'is_online': False,
#    'has_promoted_closet': False,
#    'can_view_profile': True,
#    'can_bundle': True,
#    'last_loged_on': '22/11 12:12',
#    'accepted_pay_in_methods': [{'id': 1,
#      'code': 'CREDIT_CARD',
#      'requires_credit_card': True,
#      'event_tracking_code': 'cc',
#      'icon': 'credit-card',
#      'enabled': True,
#      'translated_name': 'Carte bancaire',
#      'note': "Les informations liées à ta carte bancaire ne seront pas partagées avec le vendeur. Vinted n'enregistre pas tes informations bancaires sans ton autorisation."},
#     {'id': 4,
#      'code': 'SOFORT',
#      'requires_credit_card': False,
#      'event_tracking_code': 'sofort',
#      'icon': 'sofort',
#      'enabled': True,
#      'translated_name': 'Sofort',
#      'note': ''},
#     {'id': 16,
#      'code': 'APPLE_PAY',
#      'requires_credit_card': False,
#      'event_tracking_code': 'apple_pay',
#      'icon': 'apple-pay',
#      'enabled': True,
#      'translated_name': 'Apple Pay',
#      'note': ''},
#     {'id': 10,
#      'code': 'MANGOPAY_PAYPAL',
#      'requires_credit_card': False,
#      'event_tracking_code': 'mangopay_paypal',
#      'icon': 'paypal',
#      'enabled': True,
#      'translated_name': 'PayPal',
#      'note': ''},
#     {'id': 9,
#      'code': 'IDEAL',
#      'requires_credit_card': False,
#      'event_tracking_code': 'ideal',
#      'icon': 'ideal',
#      'enabled': True,
#      'translated_name': 'iDeal',
#      'note': ''}],
#    'localization': 'manual'},
#   'can_edit': False,
#   'can_delete': False,
#   'can_request_reservation': False,
#   'can_cancel_reservation_request': False,
#   'can_reserve': False,
#   'can_transfer': False,
#   'instant_buy': True,
#   'can_close': False,
#   'can_buy': True,
#   'can_bundle': True,
#   'can_ask_seller': True,
#   'can_favourite': False,
#   'user_login': 'milan_knaepen123',
#   'city_id': 83034,
#   'city': 'Herk-de-Stad',
#   'country': 'Belgique',
#   'nearby': None,
#   'distance': None,
#   'promoted': True,
#   'is_favourite': False,
#   'is_mobile': False,
#   'bump_badge_visible': False,
#   'brand_dto': {'id': 114196,
#    'title': 'Hasbro',
#    'slug': 'hasbro',
#    'favourite_count': 2625,
#    'pretty_favourite_count': '2.6K',
#    'item_count': 177445,
#    'pretty_item_count': '177.4K',
#    'is_visible_in_listings': True,
#    'path': '/brand/hasbro',
#    'requires_authenticity_check': False,
#    'url': 'https://www.vinted.fr/brand/hasbro',
#    'is_favourite': False,
#    'is_hated': False},
#   'url': 'https://www.vinted.fr/enfants/jeux-electroniques/749000227-bop-it-tetris',
#   'accepted_pay_in_methods': [{'id': 1,
#     'code': 'CREDIT_CARD',
#     'requires_credit_card': True,
#     'event_tracking_code': 'cc',
#     'icon': 'credit-card',
#     'enabled': True,
#     'translated_name': 'Carte bancaire',
#     'note': "Les informations liées à ta carte bancaire ne seront pas partagées avec le vendeur. Vinted n'enregistre pas tes informations bancaires sans ton autorisation."},
#    {'id': 10,
#     'code': 'MANGOPAY_PAYPAL',
#     'requires_credit_card': False,
#     'event_tracking_code': 'mangopay_paypal',
#     'icon': 'paypal',
#     'enabled': True,
#     'translated_name': 'PayPal',
#     'note': ''}],
#   'created_at': '19/11 22:00',
#   'color1': None,
#   'color2': None,
#   'material': None,
#   'status': 'Bon état',
#   'secure_purchase': True,
#   'performance': None,
#   'stats_visible': True,
#   'can_push_up': False,
#   'price': '23,00 €',
#   'discount_price': '',
#   'real_value': '',
#   'size_guide_faq_entry_id': 516,
#   'localization': 'manual'}]

# %%
import pandas as pd

# %%
df=pd.json_normalize(data['items'])

# %%
url
# Out:
# 'https://www.vinted.fr/api/v2/items?catalog_ids=1193&color_ids=&brand_ids=&size_ids=&material_ids=&status_ids=&country_ids=&city_ids=&is_for_swap=0&page=2&per_page=24&time=1606217432&search_session_id=37d91f8e-0c9f-4fcd-a64b-5802ea048fa4'

# %%
"https://www.vinted.fr/api/v2/items?catalog_ids=1193&color_ids=&brand_ids=&size_ids=&material_ids=&status_ids=&country_ids=&city_ids=&is_for_swap=0&page=3&per_page=24&time=1606217432&search_session_id=57349038-a269-48b7-baa1-30676536bd0f"
# Out:
# 'https://www.vinted.fr/api/v2/items?catalog_ids=1193&color_ids=&brand_ids=&size_ids=&material_ids=&status_ids=&country_ids=&city_ids=&is_for_swap=0&page=3&per_page=24&time=1606217432&search_session_id=57349038-a269-48b7-baa1-30676536bd0f'

# %%
df_final=pd.DataFrame()
for i in range(1,6):
    url=f'https://www.vinted.fr/api/v2/items?catalog_ids=1193&color_ids=&brand_ids=&size_ids=&material_ids=&status_ids=&country_ids=&city_ids=&is_for_swap=0&page={i}&per_page=24&time=1606217432&search_session_id=57349038-a269-48b7-baa1-30676536bd0f'
    headers=f"""accept: application/json, text/plain, */*
accept-encoding: gzip, deflate, br
accept-language: fr
cache-control: no-cache
cookie: __cfduid=def393e68d18f0de189887797435429211606217287; anon_id=377020f0-efe2-49b4-ad8a-497db4b0c9c5; __cf_bm=ac27fc9912f106a84e7f82e97c72118b8ec64717-1606217290-1800-AUpszaLeW2XXybI209bGY4RRJ6j+SW1MUxheJle8j/udzFM7qxFP/cf+ir9uwKnttDivO3gzqfqKCZGR60xe2dLHy7d9kAb2PjwLW4vaVMhVvZ/KEI3pXmQt7dgq4UftNSEPeiWnyB0CmNXMpZoBs8lraJU4s7LX/CRRC9CGTdL9hStjg0BJgMgZRoWcA/NdjQ==; G_ENABLED_IDPS=google; OptanonAlertBoxClosed=2020-11-24T11:28:18.573Z; eupubconsent-v2=CO9YU8EO9YU8EAcABBENBBCsAP_AAH_AAChQGXNf_X9fb2vj-_5999t0eY1f9_63t2wzjgeNs-8NyZ_X_J4XtmMyvB34pqYKmR4EunLBAQdlHGHcTQgAwIkVqTLsYk2MjzNKJ7JEilMbe2dYGH9vn8XT-ZKY70-v___7v3-_-___7pAy6BWABQAEQAKgAhgBFACYAFwAMwAjoBhAGHAMoAywBqADaAHhAPsA_ACAQEYARkAjgBIgCfAFLAKvAWgBaQC_AG8AOkAj0BIICYgEygJsAU2AsUBaIC2AFyALzAX0AwKBh4GIAMegZEBkYDLgEQQAIA-wC9ggCQAAUADgAPAAuAB8AHwASQAxAB_AEUAJEAZoA2gBxADkAHOAOoAf4BAwCDgEXAI0AT8AoYCHwEegJWATaAsIBaAC6AF1ALtAYgAxYBkIDKAkEoABAAC4AKAAqABkADgAHgAQAAiABUADQAHkAQwBEACYAE-...-_wCLAEYAI4ASkAq4BYoC0ALSAXMAvIBfgDCAGKANoAbiA6YDqAHoAQ2AiIBF4CQQEiAJUATYAnYBQ4CmgFWALFgWwBbIC4AFyALtAXeAwkBhoDDwGJAMYAY8AyQBk5ABEAAgAH4AQQAvgBoAD-AJEAW4AwgBlgDVAG0AOIAcgA5wB4AFLALEAYAA2QBvADtgIfAR6AlcBMQCbQFCgKQAUmArYBdAC-gGBEIGYACwAKAAZABEACoAGIAQwAmABVAC4AGIAMwAbwA9ACOAFiAMoAagA3wB3gD8AH-AQMAjABHACUgFDAKvAWgBaQC5gF--AGQANoAjgBIgC5AGEAMsAagA1wBtADiAHOAOoAdwA8ACAAEHAISARUAm0BPgE_AKWAWIAuoBgADFAGvAN4AdsA8gB_wEegJiATaApABTACpgFdgLQAXQAvoBgQDFikD4ABcAFAAVAAyABwAEAAKgAYgA0AB5AEMARAAmABPACkAFUALAAXAAxABmADmAIQAQ0AiACJAFKALEAW4AygBogDVAGyAO-AfYB-gEWAIwARwAlIBQwCrgFbALmAXkAwgBtADcAHoAReAkQBNgCdgFDgKaAVsAsUBbAC4AFyALtAYaAw8BjADIgGSAMnAA.f_gAD_gAAAAA; feature.expose.377020f0-efe2-49b4-ad8a-497db4b0c9c5=%5B%22sqp_ads%22%2C%22final_discovery_homepage%22%2C%22homepage_brand_image_5%22%2C%22nasa_delivery_instructions_redesign%22%2C%22disable_boosts_for_new_buyers%22%2C%22location_city_country%22%5D; _ga=GA1.2.1706906247.1606217303; _gid=GA1.2.1904756917.1606217303; _gat=1; _vinted_fr_session=...--69248592df3986d640d8386aad7fe9ad12a92e65; OptanonConsent=isIABGlobal=false&datestamp=Tue+Nov+24+2020+12%3A30%3A37+GMT%2B0100+(Central+European+Standard+Time)&version=6.7.0&hosts=&consentId=de152a64-3557-48e1-af64-5c3bab51b0a9&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1%2CSTACK42%3A1&geolocation=FR%3BIDF&AwaitingReconsent=false
dnt: 1
pragma: no-cache
referer: https://www.vinted.fr/vetements?catalog[]=1193&time=1606217432&page={i-1}
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36 OPR/71.0.3770.323
x-csrf-token: ikDuUVA6muVPFyyVmce3n0hTYkAD7wdHiiTwINsweaCX4bcexs3D4smcCguFWrdzb4kh1gXQPdIs5/2X7FRv2Q=="""
    headers=dict([i.split(': ') for i in headers.split('\n')])    
    response=r.get(url, headers=headers)
    data=response.json()
    df=pd.json_normalize(data['items'])
    df_final=df_final.append(df)
    print('page number',i,'is done!')
# Out:
# page number 1 is done!
# page number 2 is done!
# page number 3 is done!
# page number 4 is done!
# page number 5 is done!

# %%
df_final
# Out:
#            id                                      title  brand_id  size_id  \
# 0   759895764                     Vest black bananas 152    941716    631.0
# 1   760336496                      Silla de paseo Chicco    184768      NaN
# 2   760335588                  Cochecito de bebé Concord    290143      NaN
# 3   760286182                 Libro guante de 0 a 5 años    831036    622.0
# 4   760286655                 Libro guante de 0 a 5 años    831036    622.0
# ..        ...                                        ...       ...      ...
# 19  760652298                         Parka Guess noire         20    631.0
# 20  755402251                       Boots neige fourrée        525    599.0
# 21  733371903              Jeu de société the voice neuf    125194    631.0
# 22  760801115  Lot de cartes pokemon vmax/ gx française     191646    610.0
# 23  750801357              Épée pistolet flèche aron man         1    620.0
#
#     status_id  disposal_conditions   user_id owner_id  country_id  catalog_id  \
# 0           2                    4  45351810     None          10        1671
# 1           3                    4  45784827     None           7        1512
# 2           2                    4  45784827     None           7        1612
# 3           6                    4  36780314     None           7        1502
# 4           6                    4  36780314     None           7        1502
# ..        ...                  ...       ...      ...         ...         ...
# 19          2                    4  14496437     None          16        1647
# 20          2                    4  45347193     None          16        1658
# 21          1                    4   7956014     None          16        1726
# 22          2                    4  43202146     None          16        1726
# 23          4                    4  38209991     None          16        1730
#
#     ...  user.bundle_discount.enabled  \
# 0   ...                           NaN
# 1   ...                           NaN
# 2   ...                           NaN
# 3   ...                          True
# 4   ...                          True
# ..  ...                           ...
# 19  ...                          True
# 20  ...                           NaN
# 21  ...                          True
# 22  ...                           NaN
# 23  ...                         False
#
#     user.bundle_discount.minimal_item_count  user.bundle_discount.fraction  \
# 0                                       NaN                            NaN
# 1                                       NaN                            NaN
# 2                                       NaN                            NaN
# 3                                       2.0                            0.2
# 4                                       2.0                            0.2
# ..                                      ...                            ...
# 19                                      2.0                            0.1
# 20                                      NaN                            NaN
# 21                                      2.0                           0.05
# 22                                      NaN                            NaN
# 23                                      2.0                           0.05
#
#                        user.bundle_discount.discounts  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   [{'minimal_item_count': 2, 'fraction': '0.2'},...
# 4   [{'minimal_item_count': 2, 'fraction': '0.2'},...
# ..                                                ...
# 19  [{'minimal_item_count': 2, 'fraction': '0.1'},...
# 20                                                NaN
# 21  [{'minimal_item_count': 2, 'fraction': '0.05'}...
# 22                                                NaN
# 23  [{'minimal_item_count': 2, 'fraction': '0.05'}...
#
#     user.location_description user.photo  custom_shipment_price  \
# 0                         NaN        NaN                    NaN
# 1                         NaN        NaN                    NaN
# 2                         NaN        NaN                    NaN
# 3                         NaN        NaN                    NaN
# 4                         NaN        NaN                    NaN
# ..                        ...        ...                    ...
# 19                        NaN        NaN                    NaN
# 20                        NaN        NaN                    NaN
# 21                        NaN        NaN                    NaN
# 22                        NaN        NaN                    2.5
# 23                        NaN        NaN                    NaN
#
#     shipment_prices.domestic  shipment_prices.international  user.postal_code
# 0                        NaN                            NaN               NaN
# 1                        NaN                            NaN               NaN
# 2                        NaN                            NaN               NaN
# 3                        NaN                            NaN               NaN
# 4                        NaN                            NaN               NaN
# ..                       ...                            ...               ...
# 19                       NaN                            NaN               NaN
# 20                       NaN                            NaN               NaN
# 21                       NaN                            NaN               NaN
# 22                       2.5                            2.9               NaN
# 23                       NaN                            NaN               NaN
#
# [120 rows x 225 columns]

# %%
df_final.drop_duplicates(subset=['id'])
# Out:
#            id                                      title  brand_id  size_id  \
# 0   759895764                     Vest black bananas 152    941716    631.0
# 1   760336496                      Silla de paseo Chicco    184768      NaN
# 2   760335588                  Cochecito de bebé Concord    290143      NaN
# 3   760286182                 Libro guante de 0 a 5 años    831036    622.0
# 4   760286655                 Libro guante de 0 a 5 años    831036    622.0
# ..        ...                                        ...       ...      ...
# 19  760652298                         Parka Guess noire         20    631.0
# 20  755402251                       Boots neige fourrée        525    599.0
# 21  733371903              Jeu de société the voice neuf    125194    631.0
# 22  760801115  Lot de cartes pokemon vmax/ gx française     191646    610.0
# 23  750801357              Épée pistolet flèche aron man         1    620.0
#
#     status_id  disposal_conditions   user_id owner_id  country_id  catalog_id  \
# 0           2                    4  45351810     None          10        1671
# 1           3                    4  45784827     None           7        1512
# 2           2                    4  45784827     None           7        1612
# 3           6                    4  36780314     None           7        1502
# 4           6                    4  36780314     None           7        1502
# ..        ...                  ...       ...      ...         ...         ...
# 19          2                    4  14496437     None          16        1647
# 20          2                    4  45347193     None          16        1658
# 21          1                    4   7956014     None          16        1726
# 22          2                    4  43202146     None          16        1726
# 23          4                    4  38209991     None          16        1730
#
#     ...  user.bundle_discount.enabled  \
# 0   ...                           NaN
# 1   ...                           NaN
# 2   ...                           NaN
# 3   ...                          True
# 4   ...                          True
# ..  ...                           ...
# 19  ...                          True
# 20  ...                           NaN
# 21  ...                          True
# 22  ...                           NaN
# 23  ...                         False
#
#     user.bundle_discount.minimal_item_count  user.bundle_discount.fraction  \
# 0                                       NaN                            NaN
# 1                                       NaN                            NaN
# 2                                       NaN                            NaN
# 3                                       2.0                            0.2
# 4                                       2.0                            0.2
# ..                                      ...                            ...
# 19                                      2.0                            0.1
# 20                                      NaN                            NaN
# 21                                      2.0                           0.05
# 22                                      NaN                            NaN
# 23                                      2.0                           0.05
#
#                        user.bundle_discount.discounts  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   [{'minimal_item_count': 2, 'fraction': '0.2'},...
# 4   [{'minimal_item_count': 2, 'fraction': '0.2'},...
# ..                                                ...
# 19  [{'minimal_item_count': 2, 'fraction': '0.1'},...
# 20                                                NaN
# 21  [{'minimal_item_count': 2, 'fraction': '0.05'}...
# 22                                                NaN
# 23  [{'minimal_item_count': 2, 'fraction': '0.05'}...
#
#     user.location_description user.photo  custom_shipment_price  \
# 0                         NaN        NaN                    NaN
# 1                         NaN        NaN                    NaN
# 2                         NaN        NaN                    NaN
# 3                         NaN        NaN                    NaN
# 4                         NaN        NaN                    NaN
# ..                        ...        ...                    ...
# 19                        NaN        NaN                    NaN
# 20                        NaN        NaN                    NaN
# 21                        NaN        NaN                    NaN
# 22                        NaN        NaN                    2.5
# 23                        NaN        NaN                    NaN
#
#     shipment_prices.domestic  shipment_prices.international  user.postal_code
# 0                        NaN                            NaN               NaN
# 1                        NaN                            NaN               NaN
# 2                        NaN                            NaN               NaN
# 3                        NaN                            NaN               NaN
# 4                        NaN                            NaN               NaN
# ..                       ...                            ...               ...
# 19                       NaN                            NaN               NaN
# 20                       NaN                            NaN               NaN
# 21                       NaN                            NaN               NaN
# 22                       2.5                            2.9               NaN
# 23                       NaN                            NaN               NaN
#
# [112 rows x 225 columns]
