# %% [markdown]
# class Country:
#     def __init__():
#
#    - name
#    - code
#    - neightbour
#    - soldiers - num, who owns it etc.
#
#
# argentina = Country("argentina", "1", ["", ""]

# %% [markdown]
# country_code = {"argentina": 1, "china": 2, "india":3}
# neightbours = {1: [2], 2: [1], 3: }
#
# [country_code[1] for i in neighbour[country_code["argentina"]]]

# %%
#Country by their code

country_code = {"Afghanistan": 1, "Alaska": 2, "Alberta": 3, "Argentina": 4, "Brazil": 5, "Central America": 6, "China": 7, "Congo": 8, "East Africa": 9, "Eastern Australia": 10, "Eastern United States": 11, "Egypt": 12, "Great Britain": 13, "Greenland": 14, "Iceland": 15, "India": 16, "Indonesia": 17, "Irkutsk": 18, "Japan": 19, "Kamchatka": 20, "Madagascar": 21, "Middle East": 22, "Mongolia": 23, "New Guinea": 24, "North Africa": 25, "Northern Europe": 26, "Northwest Territory": 27, "Ontario": 28, "Peru": 29, "Quebec": 30, "Scandinavia": 31, "Siam": 32, "Siberia": 33, "South Africa": 34, "Southern Europe": 35, "Ukraine": 36, "Ural": 37, "Venezuela": 38, "Western Australia": 39, "Western Europe": 40, "Western United States": 41, "Yakutsk": 42}

# %%
class Player:
    def __init__(self, name):
        self.name = name
        self.countries = []


class country:
    def __init__(self, name, country_number, neighbours, owner):
        self.name = name
        self.country_number = country_number
        self.neighbours = neighbours
        self.owner = owner



class gameplay:
    
    all_countries = {afghanistan : country("Afghanistan", 1, [36, 22, 16, 7, 37]),
    alaska : country("Alaska", 2, [3, 27, 20]),
    alberta : country("Alberta", 3, [2, 27, 28, 41]),
    argentina : country("Argentina", 4, [5, 29]),
    brazil : country("Brazil", 5, [4, 29, 38, 25]),
    central_america : country("Central America", 6, [38, 41, 11]),
    china : country("China", 7, [23, 33, 37, 1, 16, 32]),
    congo : country("Congo", 8, [25, 9, 34]),
    east_africa : country("East Africa", 9, [22, 12, 25, 8, 34, 21]),
    eastern_australia : country("Eastern Australia", 10, [24, 17,39]),
    eastern_united_states : country("Eastern United States", 11, [30, 28, 41, 6]),
    egypt : country("Egypt", 12, [9, 25, 35, 22]),
    great_britain : country("Great Britain", 13, [15, 31, 26, 40]),
    greenland : country("Greenland", 14, [15, 30, 28, 27]),
    iceland : country("Iceland", 15, [14, 13, 31]),
    india : country("India", 16, [22, 1, 7, 32]),
    indonesia : country("Indonesia", 17, [32, 24, 39]),
    irkutsk : country("Irkutsk", 18, [42, 20, 33, 23]),
    japan : country("Japan", 19, [20, 23]),
    kamchatka : country("Kamchatka", 20, [2, 42, 18, 23, 19]),
    madagascar : country("Madagascar", 21, [9, 34]) ,
    middle_east : country("Middle East", 22, [16, 1, 36, 35, 12, 9]),
    mongolia : country("Mongolia", 23, [19, 20, 18, 33, 7]),
    new_guinea : country("New Guinea", 24, [39, 10, 17]),
    north_africa : country("North Africa", 25, [5, 35, 12, 9, 8, 40]),
    northern_europe : country("Northern Europe", 26, [36, 31, 13, 40, 35]),
    northwest_territory : country("Northwest Territory", 27, [2, 3, 14, 28]),
    ontario : country("Ontario", 28, [30, 14, 27, 3, 41, 11]),
    peru : country("Peru", 29, [4, 5, 38]),
    quebec : country("Quebec", 30, [11, 28, 14]),
    scandinavia : country("Scandinavia", 31, [36, 26, 13, 15]),
    siam : country("Siam", 32, [7, 16, 17]),
    siberia : country("Siberia", 33, [37, 7, 23, 18, 42]),
    south_africa : country("South Africa", 34, [8, 9, 21]),
    southern_europe : country("Southern Europe", 35, [40, 26, 36, 22, 12, 25]),
    ukraine : country("Ukraine", 36, [37, 1, 22, 35, 26, 31]),
    ural : country("Ural", 37, [36, 1, 7, 33]),
    venezuela : country("Venezuela", 38, [5, 6, 29]),
    western_australia : country("Western Australia", 39, [10, 17, 24]),
    western_europe : country("Western Europe", 40, [13, 25, 26, 35]),
    western_united_states : country("Western United States", 41, [3, 28, 11, 6]),
    yakutsk : country("Yakutsk", 42, [33, 18, 20])}
    
    #initiation function
    def __init__ (self, countries, soldiers):
        self.countries = countries
        self.soldiers = soldiers_number
        
    def user_turn(self, player):
        print("It's", player.name ,"turn!")
        reinforcement(player)
        attack(player)
        fortify(player)
        print(player.name, "turn is finished!")
        #propose au joueur de continuer
        #si il veut arrêter : il passe à la fortification
        #sinon, recommence la phase d'attaque
    
    #Function reinforcement
    def reinforcement(self, player):
        #ajouter une class joueur squi contient les pays
        #doit appeler l'objet joueur
        
        #reinforcement based of the number of countries
        if player.countries < 9:
            new_solidiers = 3
        else:
            new_solidiers = int(player.countries/3)+1
                
        #list of countries from a continent
        africa =  [8, 9, 12, 21, 25, 34]
        asia = [1, 7, 16, 18, 19, 20, 22, 23, 32, 33, 37, 42]
        europe = [13, 15, 26, 31, 35, 36, 40]
        north_america = [2, 3, 6, 11, 14, 27, 28, 30, 41]
        oceania = [10, 17, 24, 39]
        south_america = [4, 5, 29, 38]
        
        #reinforcement based of the continents owned
        #changer self par player car ce sera la class player qui sera appliquée sur les pays du player

        for i in player.countries:
            if africa in player.countries:
                player.soldiers += 3
            elif asia in player.countries:
                player.soldiers += 7
            elif europe in player.countries:
                player.soldiers +=5
            elif north_america in player.countries:
                player.soldiers += 5
            elif oceania in player.countries:
                player.soldiers += 2
            elif south_america in player.countries:
                player.soldiers += 2

        #placing new soldiers
        
        while new_soldiers > 0:
            print(player.countries)
            placement = input("You have", player.new_soldiers, "new soldiers. Where to you want to place them?")
            
            #have to add the error handling 
            #there is a lot of cases : bad names, not your country, lower, uppercase, not complete, no space ...
            if placement not in player.countries:
                print("This is not one of your countries! Select one among the ones you own.")
                print("The list of your countries is", player.countries)
            else:
                continue

            placement_size = input('How many soldiers?')
            if placement_size > new_soliders:
                print("You don't have that many soldiers! You can only add", new_soldiers, "new soldiers to your army.")
            elif placement_size == 0:
                print("You have to place", new_soldiers, "not 0 if you want to win!")
            else:
                #add the soldiers to the country you choose
                player.countries(placement) += placement_size
                new_soldiers -= placement_size
                
        print("Reinforcement phase is over.")


    def get_country(self, country_number):
        for i in all_countries:
            
            print(i)



    #Function Attacking    
    def attack(self, countries, soldiers, player):
        
        print("Attack phase begin.")
        print("Your empire and armies are:", player.countries)
        
        choice = input("Do you want to attack any countries? y/n")
        if choice == n:
            #go to the fortifying process  
            pass
            
        elif choice == y :
            #go to the attacking process
            #input with which country attack
            print(player.countries)
            country_attacking = input("With which you want to attack:")
            
            
            #input which country, the player want to attack
            #dans la liste des pays du joueur, quel est le pays choisi + quels sont ses voisions
            print(country_attacking.neighbours)
            country_attacked = input("In the countries below, which you want to attack:")

            
            if country_attacked not in country_attacking.neighbours:
                print("This is not a country next to your empire! Try again")
                #print countries
 
                        
            print (country_attacking, "attacks", country_attacked, "with", country_attacking.soldiers,"against", country_attacked.soldiers,"\.")
            #perhaps we can add the number of soldiers for each country
            
            #dices
            import random

            offence_dice1 = random.randint(1, 6)
            offence_dice2 = random.randint(1, 6)
            offence_dice3 = random.randint(1, 6)

            defense_dice1 = random.randint(1, 6)
            defense_dice2 = random.randint(1, 6)


            three_attack = sorted((offence_dice1, offence_dice2, offence_dice3),reverse = True)
            two_attack = sorted((offence_dice1, offence_dice2), reverse = True)
            two_defense = sorted((defense_dice1, defense_dice2), reverse = True)
            one_defense = [defense_dice1]


            ### Attack ###              
            if country_attacking.soldiers >= 3:
                if country_attacked.soldiers >= 2:
                    print(three_attack, two_defense)
                    #3 attackers vs. 2 defenders
                    if two_defense[0] >= three_attack[0]:
                        country_attacking.soldiers -= 1
                        print("Attack:", country_attacking.soldiers, "Defense:", country_attacked.soldiers)
                    else:
                        country_attacked.soldiers -= 1
                        print("Attack:", country_attacking.soldiers, "Defense:", country_attacked.soldiers)

                    if two_defense[1] >= three_attack[1]:
                        country_attacking.soldiers -= 1
                        print("Attack:", country_attacking.soldiers, "Defense:", country_attacked.soldiers)
                    else:
                        country_attacked.soldiers -= 1
                        print("Attack:", country_attacking.soldiers, "Defense:", country_attacked.soldiers)

                elif country_attacked.soldiers == 1:
                    print(three_attack, one_defense)
                    #3 attackers vs. 1 defender      
                    if one_defense[0] >= three_attack[0]:
                        country_attacking.soldiers -= 1
                        print("Attack:", country_attacking.soldiers, "Defense:", country_attacked.soldiers)
                    else:
                        country_attacked.soldiers -= 1
                        print("Attack:", country_attacking.soldiers, "Defense:", country_attacked.soldiers)


            elif (country_attacking.soldiers == 2):
                if country_attacked.soldiers >= 2:
                    print(three_attack, two_defense)
                    #2 attackers vs. 2 defenders
                    if two_defense[0] >= two_attack[0]:
                        country_attacking.soldiers -= 1
                        print("Attack:", country_attacking.soldiers, "Defense:", country_attacked.soldiers)
                    else:
                        country_attacked.soldiers -= 1
                        print("Attack:", country_attacking.soldiers, "Defense:", country_attacked.soldiers)

                    if two_defense[1] >= two_attack[1]:
                        country_attacking.soldiers -= 1
                        print("Attack:", country_attacking.soldiers, "Defense:", country_attacked.soldiers)
                    else:
                        country_attacked.soldiers -= 1
                        print("Attack:", country_attacking.soldiers, "Defense:", country_attacked.soldiers)

                elif country_attacked.soldiers == 1:
                    print(three_attack, one_defense)
                    #2 attackers vs. 1 defender      
                    if one_defense[0] >= two_attack[0]:
                        country_attacking.soldiers -= 1
                        print("Attack:", country_attacking.soldiers, "Defense:", country_attacked.soldiers)
                    else:
                        country_attacked.soldiers -= 1
                        print("Attack:", country_attacking.soldiers, "Defense:", country_attacked.soldiers)


            if country_attacked.soldiers == 0:
                #capturing a country
                #transfer of soldiers from attacking country to attacked country
                print("You conquer", country_attacked)
                print("There are", country_attacking.soldiers, "attacking soldiers left!")
                soldiers.country_attacking -= 1
                soldiers.country_attacked +=1
                country_attacked.owner = player
                
            elif country_attacking.soldiers == 1:
                print("You can't attack anymore", country_attacked)
                print("There are", country_attacked.soldiers, "defending soldiers left!")
            
                  
                  
        else:
            print("It's y for yes and n for no, and not", choice, "!")

    

        
    def fortify(self, player):
        
        #print the empire and the armies
        destination = input('Where do you want to move soldiers?')
        if destination not in player.countries:
            print ("This in not one of your countries! Choose among the countries below:")
            print (player.countries)
        else:
            departure = input('From which country do you want to move soliders to', destination, "\?")
            if departure not in player.countries:
                print("This in not one of your countries! Choose among the countries below:")
                print(player.countries)
            elif soldiers.departure == 1:
                print("You can't divide a soldier in two, choose another country.")
                print(player.countries)
            else:
                moving_soliders=input('How many soldiers?')
                if moving_soldiers > country_attacking.soldiers:
                    print("You don't have enough soldier, you can choose max", depature.countries(soldiers)-1)
                elif moving_soldiers == 0:
                    print("You have to choose between 1 and", departure.countries(soldiers)-1)
                else:
                    departure -= moving_soliders
                    destincation += moving_soldiers
# Out:
#   File "<ipython-input-4-724d4a8e1c31>", line 104
#     elif placement_size = 0:
#                         ^
# SyntaxError: invalid syntax

# %%
#Class country  with list of (but it seems useless: we can put that in one class as global attributes)
class country:
    
    {afghanistan : country("Afghanistan", 1, [36, 22, 16, 7, 37]),
    alaska : country("Alaska", 2, [3, 27, 20]),
    alberta : country("Alberta", 3, [2, 27, 28, 41]),
    argentina : country("Argentina", 4, [5, 29]),
    brazil : country("Brazil", 5, [4, 29, 38, 25]),
    central_america : country("Central America", 6, [38, 41, 11]),
    china : country("China", 7, [23, 33, 37, 1, 16, 32]),
    congo : country("Congo", 8, [25, 9, 34]),
    east_africa : country("East Africa", 9, [22, 12, 25, 8, 34, 21]),
    eastern_australia : country("Eastern Australia", 10, [24, 17,39]),
    eastern_united_states : country("Eastern United States", 11, [30, 28, 41, 6]),
    egypt : country("Egypt", 12, [9, 25, 35, 22]),
    great_britain : country("Great Britain", 13, [15, 31, 26, 40]),
    greenland : country("Greenland", 14, [15, 30, 28, 27]),
    iceland : country("Iceland", 15, [14, 13, 31]),
    india : country("India", 16, [22, 1, 7, 32]),
    indonesia : country("Indonesia", 17, [32, 24, 39]),
    irkutsk : country("Irkutsk", 18, [42, 20, 33, 23]),
    japan : country("Japan", 19, [20, 23]),
    kamchatka : country("Kamchatka", 20, [2, 42, 18, 23, 19]),
    madagascar : country("Madagascar", 21, [9, 34]) ,
    middle_east : country("Middle East", 22, [16, 1, 36, 35, 12, 9]),
    mongolia : country("Mongolia", 23, [19, 20, 18, 33, 7]),
    new_guinea : country("New Guinea", 24, [39, 10, 17]),
    north_africa : country("North Africa", 25, [5, 35, 12, 9, 8, 40]),
    northern_europe : country("Northern Europe", 26, [36, 31, 13, 40, 35]),
    northwest_territory : country("Northwest Territory", 27, [2, 3, 14, 28]),
    ontario : country("Ontario", 28, [30, 14, 27, 3, 41, 11]),
    peru : country("Peru", 29, [4, 5, 38]),
    quebec : country("Quebec", 30, [11, 28, 14]),
    scandinavia : country("Scandinavia", 31, [36, 26, 13, 15]),
    siam : country("Siam", 32, [7, 16, 17]),
    siberia : country("Siberia", 33, [37, 7, 23, 18, 42]),
    south_africa : country("South Africa", 34, [8, 9, 21]),
    southern_europe : country("Southern Europe", 35, [40, 26, 36, 22, 12, 25]),
    ukraine : country("Ukraine", 36, [37, 1, 22, 35, 26, 31]),
    ural : country("Ural", 37, [36, 1, 7, 33]),
    venezuela : country("Venezuela", 38, [5, 6, 29]),
    western_australia : country("Western Australia", 39, [10, 17, 24]),
    western_europe : country("Western Europe", 40, [13, 25, 26, 35]),
    western_united_states : country("Western United States", 41, [3, 28, 11, 6]),
    yakutsk : country("Yakutsk", 42, [33, 18, 20])}
    
    def __init__ (country, country_number, neighbours):
# Out:
#   File "<ipython-input-8-1c41b95d0c70>", line 47
#     def __init__ (country, country_number, neighbours)
#                                                       ^
# SyntaxError: invalid syntax

# %%
class country:
    
    afghanistan = country("Afghanistan", 1, [36, 22, 16, 7, 37])
    alaska = country("Alaska", 2, [3, 27, 20])
    alberta = country("Alberta", 3, [2, 27, 28, 41])
    argentina = country("Argentina", 4, [5, 29]),
    brazil = country("Brazil", 5, [4, 29, 38, 25])
    central_america = country("Central America", 6, [38, 41, 11])
    china = country("China", 7, [23, 33, 37, 1, 16, 32])
    congo = country("Congo", 8, [25, 9, 34])
    east_africa = country("East Africa", 9, [22, 12, 25, 8, 34, 21])
    eastern_australia = country("Eastern Australia", 10, [24, 17,39])
    eastern_united_states = country("Eastern United States", 11, [30, 28, 41, 6])
    egypt = country("Egypt", 12, [9, 25, 35, 22])
    great_britain = country("Great Britain", 13, [15, 31, 26, 40])
    greenland = country("Greenland", 14, [15, 30, 28, 27])
    iceland = country("Iceland", 15, [14, 13, 31])
    india = country("India", 16, [22, 1, 7, 32])
    indonesia = country("Indonesia", 17, [32, 24, 39])
    irkutsk = country("Irkutsk", 18, [42, 20, 33, 23])
    japan = country("Japan", 19, [20, 23])
    kamchatka = country("Kamchatka", 20, [2, 42, 18, 23, 19])
    madagascar = country("Madagascar", 21, [9, 34]) 
    middle_east = country("Middle East", 22, [16, 1, 36, 35, 12, 9])
    mongolia = country("Mongolia", 23, [19, 20, 18, 33, 7])
    new_guinea = country("New Guinea", 24, [39, 10, 17])
    north_africa = country("North Africa", 25, [5, 35, 12, 9, 8, 40])
    northern_europe = country("Northern Europe", 26, [36, 31, 13, 40, 35])
    northwest_territory = country("Northwest Territory", 27, [2, 3, 14, 28])
    ontario = country("Ontario", 28, [30, 14, 27, 3, 41, 11])
    peru = country("Peru", 29, [4, 5, 38])
    quebec = country("Quebec", 30, [11, 28, 14])
    scandinavia = country("Scandinavia", 31, [36, 26, 13, 15])
    siam = country("Siam", 32, [7, 16, 17])
    siberia = country("Siberia", 33, [37, 7, 23, 18, 42])
    south_africa = country("South Africa", 34, [8, 9, 21])
    southern_europe = country("Southern Europe", 35, [40, 26, 36, 22, 12, 25])
    ukraine = country("Ukraine", 36, [37, 1, 22, 35, 26, 31])
    ural = country("Ural", 37, [36, 1, 7, 33])
    venezuela = country("Venezuela", 38, [5, 6, 29])
    western_australia = country("Western Australia", 39, [10, 17, 24])
    western_europe = country("Western Europe", 40, [13, 25, 26, 35])
    western_united_states= country("Western United States", 41, [3, 28, 11, 6])
    yakutsk = country("Yakutsk", 42, [33, 18, 20])
    
    def __init__ (self, owner, soldiers):
        self.owner = owner
        self.soldiers = soldiers_number
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-901ab91f4969> in <module>
# ----> 1 class country:
#       2
#       3     afghanistan = country("Afghanistan", 1, [36, 22, 16, 7, 37])
#       4     alaska = country("Alaska", 2, [3, 27, 20])
#       5     alberta = country("Alberta", 3, [2, 27, 28, 41])
#
# <ipython-input-6-901ab91f4969> in country()
#       1 class country:
#       2
# ----> 3     afghanistan = country("Afghanistan", 1, [36, 22, 16, 7, 37])
#       4     alaska = country("Alaska", 2, [3, 27, 20])
#       5     alberta = country("Alberta", 3, [2, 27, 28, 41])
#
# NameError: name 'country' is not defined

# %%
# test not useful for the moment
import random

offence_dice1 = random.randint(1, 6)
offence_dice2 = random.randint(1, 6)
offence_dice3 = random.randint(1, 6)

defense_dice1 = random.randint(1, 6)
defense_dice2 = random.randint(1, 6)

print(offence_dice1, offence_dice2, offence_dice3,defense_dice1, defense_dice2)
      
      
if defense_dice1 >= max(int(offence_dice1), int(offence_dice2), int(offence_dice3)):
    print ("The defense has won")
elif defense_dice2 >= max(int(offence_dice1), int(offence_dice2), int(offence_dice3)):
    print ("The defense has won")
else:
    print ("The offence has won")
# Out:
# 2 1 5 5 1
# The defense has won

# %%
#Below are the continents. It can be useful for the reinforcement step.

{africa:
    {congo : country("Congo", 8, [25, 9, 34]),
     east_africa : country("East Africa", 9, [22, 12, 25, 8, 34, 21]),
     egypt : country("Egypt", 12, [9, 25, 35, 22]),
     madagascar : country("Madagascar", 21, [9, 34]),
     north_africa : country("North Africa", 25, [5, 35, 12, 9, 8, 40]),
     south_africa : country("South Africa", 34, [8, 9, 21])
    },
 
asia:
    {afghanistan : country("Afghanistan", 1, [36, 22, 16, 7, 37]),
     china : country("China", 7, [23, 33, 37, 1, 16, 32]),
     india : country("India", 16, [22, 1, 7, 32]),
     irkutsk : country("Irkutsk", 18, [42, 20, 33, 23]),
     japan : country("Japan", 19, [20, 23]),
     kamchatka : country("Kamchatka", 20, [2, 42, 18, 23, 19]),
     middle_east : country("Middle East", 22, [16, 1, 36, 35, 12, 9]),
     mongolia : country("Mongolia", 23, [19, 20, 18, 33, 7]),
     siam : country("Siam", 32, [7, 16, 17]),
     siberia : country("Siberia", 33, [37, 7, 23, 18, 42]),
     ural : country("Ural", 37, [36, 1, 7, 33]),
     yakutsk : country("Yakutsk", 42, [33, 18, 20])
    },

 europe:
     {great_britain : country("Great Britain", 13, [15, 31, 26, 40]),
      iceland : country("Iceland", 15, [14, 13, 31]),
      northern_europe : country("Northern Europe", 26, [36, 31, 13, 40, 35]),
      scandinavia : country("Scandinavia", 31, [36, 26, 13, 15]),
      southern_europe : country("Southern Europe", 35, [40, 26, 36, 22, 12, 25]),
      ukraine : country("Ukraine", 36, [37, 1, 22, 35, 26, 31]),
      western_europe : country("Western Europe", 40, [13, 25, 26, 35])
     },
    
 north_america:   
    {alaska : country("Alaska", 2, [3, 27, 20]),
     alberta : country("Alberta", 3, [2, 27, 28, 41]),
     central_america : country("Central America", 6, [38, 41, 11]),
     eastern_united_states : country("Eastern United States", 11, [30, 28, 41, 6]),
     greenland : country("Greenland", 14, [15, 30, 28, 27]),
     northwest_territory : country("Northwest Territory", 27, [2, 3, 14, 28]),
     ontario : country("Ontario", 28, [30, 14, 27, 3, 41, 11]),
     quebec : country("Quebec", 30, [11, 28, 14]),
     western_united_states : country("Western United States", 41, [3, 28, 11, 6])
    },

 
 oceania:
     {eastern_australia : country("Eastern Australia", 10, [24, 17,39]),   
      indonesia : country("Indonesia", 17, [32, 24, 39]),
      new_guinea : country("New Guinea", 24, [39, 10, 17]),
      western_australia : country("Western Australia", 39, [10, 17, 24])
     },
 
 south_america:
    {argentina : country("Argentina", 4, [5, 29]),
     brazil : country("Brazil", 5, [4, 29, 38, 25]),
     peru : country("Peru", 29, [4, 5, 38]),
     venezuela : country("Venezuela", 38, [5, 6, 29])
    }
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-73393953b1a4> in <module>
# ----> 1 {africa:
#       2     {congo : country("Congo", 8, [25, 9, 34]),
#       3      east_africa : country("East Africa", 9, [22, 12, 25, 8, 34, 21]),
#       4      egypt : country("Egypt", 12, [9, 25, 35, 22]),
#       5      madagascar : country("Madagascar", 21, [9, 34]),
#
# NameError: name 'africa' is not defined
